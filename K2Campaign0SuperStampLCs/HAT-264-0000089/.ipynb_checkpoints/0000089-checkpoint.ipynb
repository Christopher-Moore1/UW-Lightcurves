# %%
from astropy.table import Table
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
outpath='HAT-264.rlc.tfalc'
data=Table.read(outpath,format='ascii')
t=data['col2']
mag=data['col8']

# %%
plt.figure(figsize=(20,8))
plt.plot(t,mag,'yo',markersize=10,label='HAT-264-0000089')
plt.ylabel('Relative Magnitude')
plt.xlabel('time (BJD-2454833)')
# Out:
# Text(0.5, 0, 'time (BJD-2454833)')

# %%
import astrobase
from astrobase import periodbase, checkplot
periodbase.use_astropy_bls()
# Out:
# [I 200811 15:14:22 __init__:84] An Astropy implementation of BLS is available because Astropy >= 3.1.
# [I 200811 15:14:22 __init__:86] If you want to use it as the default periodbase BLS runner, call the periodbase.use_astropy_bls() function.

# %%
dates=data['col2']
fluxes=data['col8']
errs=fluxes*0.01

# %%
glsp = periodbase.pgen_lsp(dates,fluxes,errs)
# Out:
# [I 200811 15:14:22 zgls:597] using autofreq with 1580 frequency points, start P = 0.100, end P = 31.690
# [I 200811 15:14:22 zgls:607] using 6 workers...

# %%
cp = checkplot.checkplot_png(glsp, dates, fluxes, errs, magsarefluxes=True)
# Out:
# [I 200811 15:14:25 nonphysical:216] spline fit done. nknots = 13,  chisq = 13308235.08154, reduced chisq = 9785.46697
# [I 200811 15:14:25 png:696] plotting phased LC with period 0.333574, epoch 1954.82057
# [I 200811 15:14:25 nonphysical:216] spline fit done. nknots = 13,  chisq = 13397887.91252, reduced chisq = 9851.38817
# [I 200811 15:14:25 png:696] plotting phased LC with period 0.166787, epoch 1954.98402
# [I 200811 15:14:25 nonphysical:216] spline fit done. nknots = 13,  chisq = 13300705.89305, reduced chisq = 9772.74496
# [I 200811 15:14:25 png:696] plotting phased LC with period 0.667149, epoch 1971.16597
# [I 200811 15:14:25 nonphysical:216] spline fit done. nknots = 13,  chisq = 13320721.38766, reduced chisq = 9787.45142
# [I 200811 15:14:25 png:696] plotting phased LC with period 0.110571, epoch 1940.47757
# [I 200811 15:14:25 nonphysical:216] spline fit done. nknots = 13,  chisq = 13229499.55589, reduced chisq = 9720.42583
# [I 200811 15:14:25 png:696] plotting phased LC with period 4.801449, epoch 1940.47757
# [I 200811 15:14:25 nonphysical:216] spline fit done. nknots = 13,  chisq = 13330057.96942, reduced chisq = 9794.31151
# [I 200811 15:14:25 png:696] plotting phased LC with period 0.134735, epoch 1954.75927
# [I 200811 15:14:25 nonphysical:216] spline fit done. nknots = 13,  chisq = 13387442.06711, reduced chisq = 9836.47470
# [I 200811 15:14:25 png:696] plotting phased LC with period 0.295612, epoch 1954.37107
# [I 200811 15:14:26 png:1233] checkplot done -> checkplot.png

# %%
from IPython.display import Image
Image('HAT-264-0000089-checkplot.png')

# %%
glsp
# Out:
# {'bestperiod': 0.33357435968421095,
#  'bestlspval': 0.01598477040482561,
#  'nbestpeaks': 5,
#  'nbestlspvals': [0.01598477040482561,
#   0.014307152856957784,
#   0.010707758860968895,
#   0.008902579856817402,
#   0.008484910207942876],
#  'nbestperiods': [0.33357435968421095,
#   0.11057070540823459,
#   4.801449116666673,
#   0.13473454153911582,
#   0.29561160606343323],
#  'lspvals': array([0.00202817, 0.00231219, 0.00250137, ..., 0.00129329, 0.00122677,
#         0.00163921]),
#  'omegas': array([ 0.19827301,  0.23792761,  0.27758222, ..., 62.7335807 ,
#         62.7732353 , 62.8128899 ]),
#  'periods': array([31.68956417, 26.40797014, 22.63540298, ...,  0.10015665,
#          0.10009338,  0.10003019]),
#  'method': 'gls',
#  'kwargs': {'startp': None,
#   'endp': None,
#   'stepsize': 0.0001,
#   'autofreq': True,
#   'periodepsilon': 0.1,
#   'nbestpeaks': 5,
#   'sigclip': 10.0}}

# %%
print('LS algorithm:',(glsp['nbestperiods']),'(days)')
# Out:
# LS algorithm: [0.33357435968421095, 0.11057070540823459, 4.801449116666673, 0.13473454153911582, 0.29561160606343323] (days)

# %%
bls=periodbase.bls_parallel_pfind(dates,fluxes,errs,magsarefluxes=True)
# Out:
# [I 200811 15:14:26 abls:919] min P: 0.1, max P: 100.0, nfreq: 126632, minfreq: 0.01, maxfreq: 10.0
# [I 200811 15:14:26 abls:922] autofreq = True: using AUTOMATIC values for freq stepsize: 7.889032447996576e-05, ndurations: 100, min transit duration: 0.01, max transit duration: 0.4
# [W 200811 15:14:26 abls:964] the requested max P = 100.000 is larger than the time base of the observations = 31.690,  will make minfreq = 2 x 1/timebase
# [W 200811 15:14:26 abls:969] new minfreq: 0.06311225958397261, maxfreq: 10.0
# [I 200811 15:14:26 abls:980] using 6 workers...
# [I 200811 15:14:26 abls:1090] worker 1: minfreq = 0.063112, nfreqs = 21105
# [I 200811 15:14:26 abls:1090] worker 2: minfreq = 1.728093, nfreqs = 21105
# [I 200811 15:14:26 abls:1090] worker 3: minfreq = 3.393073, nfreqs = 21105
# [I 200811 15:14:26 abls:1090] worker 4: minfreq = 5.058053, nfreqs = 21105
# [I 200811 15:14:26 abls:1090] worker 5: minfreq = 6.723033, nfreqs = 21105
# [I 200811 15:14:26 abls:1090] worker 6: minfreq = 8.388014, nfreqs = 21107
# [I 200811 15:14:26 abls:1092] running...
# [E 200811 15:14:39 abls:1125] no finite periodogram values for this mag series, skipping...

# %%
cp = checkplot.checkplot_png(bls, dates, fluxes, errs, magsarefluxes=True)
# Out:
# [W 200811 15:14:39 png:1142] no best period found for this object, skipping...

# %%
Image('checkplot.png')
# This is the same checkplot from before because no best period was found to create a new checkplot.

# %%
spdm = periodbase.stellingwerf_pdm(dates,fluxes,errs,magsarefluxes=True)
# Out:
# [I 200811 15:14:39 spdm:337] using autofreq with 1580 frequency points, start P = 0.100, end P = 31.690
# [I 200811 15:14:39 spdm:349] using 6 workers...

# %%
cp = checkplot.checkplot_png(spdm, dates, fluxes, errs, magsarefluxes=True)
Image('HAT-264-0000089-checkplot-spdm.png')
# Out:
# [I 200811 15:14:42 nonphysical:216] spline fit done. nknots = 13,  chisq = 13352759.74356, reduced chisq = 9810.99173
# [I 200811 15:14:42 png:696] plotting phased LC with period 6.094147, epoch 1964.85254
# [I 200811 15:14:42 nonphysical:216] spline fit done. nknots = 13,  chisq = 13445999.09471, reduced chisq = 9879.49970
# [I 200811 15:14:42 png:696] plotting phased LC with period 3.047073, epoch 1964.85254
# [I 200811 15:14:42 nonphysical:216] spline fit done. nknots = 13,  chisq = 13358303.72175, reduced chisq = 9815.06519
# [I 200811 15:14:42 png:696] plotting phased LC with period 12.188294, epoch 1964.85254
# [I 200811 15:14:42 nonphysical:216] spline fit done. nknots = 13,  chisq = 13358303.72175, reduced chisq = 9815.06519
# [I 200811 15:14:42 png:696] plotting phased LC with period 12.188294, epoch 1964.85254
# [I 200811 15:14:42 nonphysical:216] spline fit done. nknots = 13,  chisq = 13198431.74523, reduced chisq = 9697.59864
# [I 200811 15:14:42 png:696] plotting phased LC with period 0.121789, epoch 1940.47757
# [I 200811 15:14:42 nonphysical:216] spline fit done. nknots = 13,  chisq = 13264633.84027, reduced chisq = 9746.24088
# [I 200811 15:14:42 png:696] plotting phased LC with period 22.635403, epoch 1962.99325
# [I 200811 15:14:42 nonphysical:216] spline fit done. nknots = 13,  chisq = 13217632.62000, reduced chisq = 9711.70655
# [I 200811 15:14:42 png:696] plotting phased LC with period 8.802657, epoch 1958.06920
# [I 200811 15:14:43 png:1233] checkplot done -> checkplot.png

# %%
print('PDM algorithm:',(spdm['nbestperiods']),'(days)')
# Out:
# PDM algorithm: [6.094146955769239, 12.188293911538478, 0.12178925507302088, 22.635402978571456, 8.8026567138889] (days)
