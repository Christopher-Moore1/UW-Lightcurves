# %%
from astropy.table import Table
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
outpath='HAT-264-0001127.rlc.tfalc'
data=Table.read(outpath,format='ascii')
t=data['col2']
mag=data['col8']

# %%
plt.figure(figsize=(20,8))
plt.plot(t,mag,'yo',markersize=10,label='HAT-264-0001127')
plt.ylabel('Relative Magnitude')
plt.xlabel('time (BJD-2454833)')
# Out:
# Text(0.5, 0, 'time (BJD-2454833)')

# %%
import astrobase
from astrobase import periodbase, checkplot
periodbase.use_astropy_bls()
# Out:
# [I 200819 11:25:09 __init__:84] An Astropy implementation of BLS is available because Astropy >= 3.1.
# [I 200819 11:25:09 __init__:86] If you want to use it as the default periodbase BLS runner, call the periodbase.use_astropy_bls() function.

# %%
dates=data['col2']
fluxes=data['col8']
errs=fluxes*0.01

# %%
glsp = periodbase.pgen_lsp(dates,fluxes,errs)
# Out:
# [I 200819 11:25:18 zgls:597] using autofreq with 1580 frequency points, start P = 0.100, end P = 31.690
# [I 200819 11:25:18 zgls:607] using 6 workers...

# %%
cp = checkplot.checkplot_png(glsp, dates, fluxes, errs)
# Out:
# [I 200819 11:25:21 nonphysical:216] spline fit done. nknots = 13,  chisq = 13277443.23428, reduced chisq = 9930.77280
# [I 200819 11:25:21 png:696] plotting phased LC with period 0.125354, epoch 1960.90921
# [I 200819 11:25:22 nonphysical:216] spline fit done. nknots = 13,  chisq = 13304935.64094, reduced chisq = 9951.33556
# [I 200819 11:25:22 png:696] plotting phased LC with period 0.062677, epoch 1940.47757
# [I 200819 11:25:22 nonphysical:216] spline fit done. nknots = 13,  chisq = 13299547.87091, reduced chisq = 9947.30581
# [I 200819 11:25:22 png:696] plotting phased LC with period 0.250709, epoch 1951.51064
# [I 200819 11:25:22 nonphysical:216] spline fit done. nknots = 13,  chisq = 13277244.57846, reduced chisq = 9930.62422
# [I 200819 11:25:22 png:696] plotting phased LC with period 0.196342, epoch 1940.47757
# [I 200819 11:25:22 nonphysical:216] spline fit done. nknots = 13,  chisq = 13296693.23663, reduced chisq = 9952.61470
# [I 200819 11:25:22 png:696] plotting phased LC with period 1.267583, epoch 1940.47757
# [I 200819 11:25:22 nonphysical:216] spline fit done. nknots = 13,  chisq = 13307815.79276, reduced chisq = 9953.48975
# [I 200819 11:25:22 png:696] plotting phased LC with period 0.105985, epoch 1970.47129
# [I 200819 11:25:22 nonphysical:216] spline fit done. nknots = 13,  chisq = 13268542.29378, reduced chisq = 9924.11540
# [I 200819 11:25:22 png:696] plotting phased LC with period 0.796220, epoch 1940.47757
# [I 200819 11:25:23 png:1233] checkplot done -> checkplot.png

# %%
from IPython.display import Image
Image('0001127-checkplot-glsp.png')

# %%
glsp
# Out:
# {'bestperiod': 0.12535428864715206,
#  'bestlspval': 0.009607795192832324,
#  'nbestpeaks': 5,
#  'nbestlspvals': [0.009607795192832324,
#   0.007737408840578936,
#   0.007662140291409318,
#   0.006360481537896641,
#   0.0058538666085499805],
#  'nbestperiods': [0.12535428864715206,
#   0.1963417854399011,
#   1.2675825668000016,
#   0.10598516444816065,
#   0.7962202052763827],
#  'lspvals': array([0.00051557, 0.00037746, 0.00047106, ..., 0.00177491, 0.00169034,
#         0.00206453]),
#  'omegas': array([ 0.19827301,  0.23792761,  0.27758222, ..., 62.7335807 ,
#         62.7732353 , 62.8128899 ]),
#  'periods': array([31.68956417, 26.40797014, 22.63540298, ...,  0.10015665,
#          0.10009338,  0.10003019]),
#  'method': 'gls',
#  'kwargs': {'startp': None,
#   'endp': None,
#   'stepsize': 0.0001,
#   'autofreq': True,
#   'periodepsilon': 0.1,
#   'nbestpeaks': 5,
#   'sigclip': 10.0}}

# %%
print('LS algorithm:',(glsp['nbestperiods']),'(days)')
# Out:
# LS algorithm: [0.12535428864715206, 0.1963417854399011, 1.2675825668000016, 0.10598516444816065, 0.7962202052763827] (days)

# %%
bls=periodbase.bls_parallel_pfind(dates,fluxes,errs)
# Out:
# [I 200819 11:25:51 abls:919] min P: 0.1, max P: 100.0, nfreq: 126632, minfreq: 0.01, maxfreq: 10.0
# [I 200819 11:25:51 abls:922] autofreq = True: using AUTOMATIC values for freq stepsize: 7.889032447996576e-05, ndurations: 100, min transit duration: 0.01, max transit duration: 0.4
# [W 200819 11:25:51 abls:964] the requested max P = 100.000 is larger than the time base of the observations = 31.690,  will make minfreq = 2 x 1/timebase
# [W 200819 11:25:51 abls:969] new minfreq: 0.06311225958397261, maxfreq: 10.0
# [I 200819 11:25:51 abls:980] using 6 workers...
# [I 200819 11:25:51 abls:1090] worker 1: minfreq = 0.063112, nfreqs = 21105
# [I 200819 11:25:51 abls:1090] worker 2: minfreq = 1.728093, nfreqs = 21105
# [I 200819 11:25:51 abls:1090] worker 3: minfreq = 3.393073, nfreqs = 21105
# [I 200819 11:25:51 abls:1090] worker 4: minfreq = 5.058053, nfreqs = 21105
# [I 200819 11:25:51 abls:1090] worker 5: minfreq = 6.723033, nfreqs = 21105
# [I 200819 11:25:51 abls:1090] worker 6: minfreq = 8.388014, nfreqs = 21107
# [I 200819 11:25:51 abls:1092] running...
# [E 200819 11:26:02 abls:1125] no finite periodogram values for this mag series, skipping...

# %%
cp = checkplot.checkplot_png(bls, dates, fluxes, errs)
# Out:
# [W 200819 11:26:02 png:1142] no best period found for this object, skipping...

# %%
spdm = periodbase.stellingwerf_pdm(dates,fluxes,errs)
# Out:
# [I 200819 11:26:07 spdm:337] using autofreq with 1580 frequency points, start P = 0.100, end P = 31.690
# [I 200819 11:26:07 spdm:349] using 6 workers...

# %%
cp = checkplot.checkplot_png(spdm, dates, fluxes, errs)
# Out:
# [I 200819 11:26:10 nonphysical:216] spline fit done. nknots = 13,  chisq = 13319466.50134, reduced chisq = 9962.20382
# [I 200819 11:26:10 png:696] plotting phased LC with period 2.779786, epoch 1940.47757
# [I 200819 11:26:10 nonphysical:216] spline fit done. nknots = 13,  chisq = 13280660.97205, reduced chisq = 9933.17949
# [I 200819 11:26:10 png:696] plotting phased LC with period 1.389893, epoch 1940.47757
# [I 200819 11:26:10 nonphysical:216] spline fit done. nknots = 13,  chisq = 13317931.75983, reduced chisq = 9961.05592
# [I 200819 11:26:10 png:696] plotting phased LC with period 5.559573, epoch 1940.47757
# [I 200819 11:26:10 nonphysical:216] spline fit done. nknots = 13,  chisq = 13353550.60812, reduced chisq = 9987.69679
# [I 200819 11:26:10 png:696] plotting phased LC with period 8.339359, epoch 1940.47757
# [I 200819 11:26:10 nonphysical:216] spline fit done. nknots = 13,  chisq = 13383197.57126, reduced chisq = 10009.87103
# [I 200819 11:26:10 png:696] plotting phased LC with period 0.206044, epoch 1940.47757
# [I 200819 11:26:10 nonphysical:216] spline fit done. nknots = 13,  chisq = 13420781.98987, reduced chisq = 10037.98204
# [I 200819 11:26:10 png:696] plotting phased LC with period 0.780531, epoch 1944.38001
# [I 200819 11:26:10 nonphysical:216] spline fit done. nknots = 13,  chisq = 13302486.70137, reduced chisq = 9949.50389
# [I 200819 11:26:10 png:696] plotting phased LC with period 2.400725, epoch 1940.47757
# [I 200819 11:26:11 png:1233] checkplot done -> checkplot.png

# %%
Image('0001127-checkplot-spdm.png')

# %%
print('PDM algorithm:',(spdm['nbestperiods']),'(days)')
# Out:
# PDM algorithm: [2.779786330701758, 8.339358992105273, 0.20604398029909, 0.7805311371921192, 2.4007245583333363] (days)
