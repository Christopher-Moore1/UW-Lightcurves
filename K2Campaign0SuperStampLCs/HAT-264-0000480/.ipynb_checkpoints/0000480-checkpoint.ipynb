# %%
from astropy.table import Table
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
outpath='HAT-264-0000480.rlc.tfalc'
data=Table.read(outpath,format='ascii')
t=data['col2']
mag=data['col8']

# %%
plt.figure(figsize=(20,8))
plt.plot(t,mag,'yo',markersize=10,label='HAT-264-0000480')
plt.ylabel('Relative Magnitude')
plt.xlabel('time (BJD-2454833)')
# Out:
# Text(0.5, 0, 'time (BJD-2454833)')

# %%
import astrobase
from astrobase import periodbase, checkplot
periodbase.use_astropy_bls()
# Out:
# [I 200815 13:46:41 __init__:84] An Astropy implementation of BLS is available because Astropy >= 3.1.
# [I 200815 13:46:41 __init__:86] If you want to use it as the default periodbase BLS runner, call the periodbase.use_astropy_bls() function.

# %%
dates=data['col2']
fluxes=data['col8']
errs=fluxes*0.01

# %%
glsp = periodbase.pgen_lsp(dates,fluxes,errs)
# Out:
# [I 200815 13:46:43 zgls:597] using autofreq with 1580 frequency points, start P = 0.100, end P = 31.690
# [I 200815 13:46:43 zgls:607] using 6 workers...

# %%
cp = checkplot.checkplot_png(glsp, dates, fluxes, errs)
# Out:
# [I 200815 13:46:47 nonphysical:216] spline fit done. nknots = 13,  chisq = 13317961.28841, reduced chisq = 9792.61859
# [I 200815 13:46:47 png:696] plotting phased LC with period 0.509478, epoch 1940.47765
# [I 200815 13:46:47 nonphysical:216] spline fit done. nknots = 13,  chisq = 13402543.71166, reduced chisq = 9854.81155
# [I 200815 13:46:47 png:696] plotting phased LC with period 0.254739, epoch 1956.27129
# [I 200815 13:46:47 nonphysical:216] spline fit done. nknots = 13,  chisq = 13265281.80919, reduced chisq = 9753.88368
# [I 200815 13:46:47 png:696] plotting phased LC with period 1.018957, epoch 1940.47765
# [I 200815 13:46:47 nonphysical:216] spline fit done. nknots = 13,  chisq = 13315917.21711, reduced chisq = 9791.11560
# [I 200815 13:46:47 png:696] plotting phased LC with period 0.184028, epoch 1940.47765
# [I 200815 13:46:47 nonphysical:216] spline fit done. nknots = 13,  chisq = 13315451.69399, reduced chisq = 9790.77330
# [I 200815 13:46:47 png:696] plotting phased LC with period 0.317531, epoch 1959.84684
# [I 200815 13:46:48 nonphysical:216] spline fit done. nknots = 13,  chisq = 13267601.67580, reduced chisq = 9755.58947
# [I 200815 13:46:48 png:696] plotting phased LC with period 0.284978, epoch 1945.89202
# [I 200815 13:46:48 nonphysical:216] spline fit done. nknots = 13,  chisq = 13207097.91056, reduced chisq = 9711.10140
# [I 200815 13:46:48 png:696] plotting phased LC with period 0.160535, epoch 1940.47765
# [I 200815 13:46:49 png:1233] checkplot done -> checkplot.png

# %%
from IPython.display import Image
Image('0000480-checkplot-glsp.png')

# %%
glsp
# Out:
# {'bestperiod': 0.509478353054661,
#  'bestlspval': 0.016640482201126912,
#  'nbestpeaks': 5,
#  'nbestlspvals': [0.016640482201126912,
#   0.01389905605308549,
#   0.013867296280395616,
#   0.0132836666229216,
#   0.013077909954189273],
#  'nbestperiods': [0.509478353054661,
#   0.18402760487804834,
#   0.3175305967935864,
#   0.2849779996402871,
#   0.1605347191489358],
#  'lspvals': array([0.00104921, 0.00158599, 0.00173431, ..., 0.00592813, 0.00428144,
#         0.00200172]),
#  'omegas': array([ 0.19827308,  0.23792769,  0.27758231, ..., 62.7336017 ,
#         62.77325632, 62.81291093]),
#  'periods': array([31.68955356, 26.4079613 , 22.6353954 , ...,  0.10015662,
#          0.10009335,  0.10003016]),
#  'method': 'gls',
#  'kwargs': {'startp': None,
#   'endp': None,
#   'stepsize': 0.0001,
#   'autofreq': True,
#   'periodepsilon': 0.1,
#   'nbestpeaks': 5,
#   'sigclip': 10.0}}

# %%
print('LS algorithm:',(glsp['nbestperiods']),'(days)')
# Out:
# LS algorithm: [0.509478353054661, 0.18402760487804834, 0.3175305967935864, 0.2849779996402871, 0.1605347191489358] (days)

# %%
bls=periodbase.bls_parallel_pfind(dates,fluxes,errs)
# Out:
# [I 200815 13:47:13 abls:919] min P: 0.1, max P: 100.0, nfreq: 126632, minfreq: 0.01, maxfreq: 10.0
# [I 200815 13:47:13 abls:922] autofreq = True: using AUTOMATIC values for freq stepsize: 7.889035089328681e-05, ndurations: 100, min transit duration: 0.01, max transit duration: 0.4
# [W 200815 13:47:13 abls:964] the requested max P = 100.000 is larger than the time base of the observations = 31.690,  will make minfreq = 2 x 1/timebase
# [W 200815 13:47:13 abls:969] new minfreq: 0.06311228071462945, maxfreq: 10.0
# [I 200815 13:47:13 abls:980] using 6 workers...
# [I 200815 13:47:13 abls:1090] worker 1: minfreq = 0.063112, nfreqs = 21105
# [I 200815 13:47:13 abls:1090] worker 2: minfreq = 1.728093, nfreqs = 21105
# [I 200815 13:47:13 abls:1090] worker 3: minfreq = 3.393074, nfreqs = 21105
# [I 200815 13:47:13 abls:1090] worker 4: minfreq = 5.058055, nfreqs = 21105
# [I 200815 13:47:13 abls:1090] worker 5: minfreq = 6.723036, nfreqs = 21105
# [I 200815 13:47:13 abls:1090] worker 6: minfreq = 8.388017, nfreqs = 21107
# [I 200815 13:47:13 abls:1092] running...
# [E 200815 13:47:26 abls:1125] no finite periodogram values for this mag series, skipping...

# %%
cp = checkplot.checkplot_png(bls, dates, fluxes, errs)
# Out:
# [W 200815 13:47:39 png:1142] no best period found for this object, skipping...

# %%
spdm = periodbase.stellingwerf_pdm(dates,fluxes,errs)
# Out:
# [I 200815 13:47:43 spdm:337] using autofreq with 1580 frequency points, start P = 0.100, end P = 31.690
# [I 200815 13:47:43 spdm:349] using 6 workers...

# %%
cp = checkplot.checkplot_png(spdm, dates, fluxes, errs)
# Out:
# [I 200815 13:47:50 nonphysical:216] spline fit done. nknots = 13,  chisq = 13290845.71796, reduced chisq = 9779.87176
# [I 200815 13:47:50 png:696] plotting phased LC with period 15.844777, epoch 1956.29172
# [I 200815 13:47:50 nonphysical:216] spline fit done. nknots = 13,  chisq = 13407050.20926, reduced chisq = 9865.37911
# [I 200815 13:47:50 png:696] plotting phased LC with period 7.922388, epoch 1948.38468
# [I 200815 13:47:50 nonphysical:216] spline fit done. nknots = 13,  chisq = 13506583.09735, reduced chisq = 9938.61891
# [I 200815 13:47:50 png:696] plotting phased LC with period 31.689554, epoch 1972.12634
# [I 200815 13:47:50 nonphysical:216] spline fit done. nknots = 13,  chisq = 13407050.20926, reduced chisq = 9865.37911
# [I 200815 13:47:50 png:696] plotting phased LC with period 7.922388, epoch 1948.38468
# [I 200815 13:47:50 nonphysical:216] spline fit done. nknots = 13,  chisq = 13430563.31485, reduced chisq = 9875.41420
# [I 200815 13:47:50 png:696] plotting phased LC with period 0.176053, epoch 1972.16720
# [I 200815 13:47:50 nonphysical:216] spline fit done. nknots = 13,  chisq = 13385148.17262, reduced chisq = 9842.02072
# [I 200815 13:47:50 png:696] plotting phased LC with period 1.842416, epoch 1940.47765
# [I 200815 13:47:50 nonphysical:216] spline fit done. nknots = 13,  chisq = 13434967.78804, reduced chisq = 9885.92185
# [I 200815 13:47:50 png:696] plotting phased LC with period 0.117369, epoch 1961.60396
# [I 200815 13:47:51 png:1233] checkplot done -> checkplot.png

# %%
Image('0000480-checkplot-spdm.png')

# %%
print('PDM algorithm:',(spdm['nbestperiods']),'(days)')
# Out:
# PDM algorithm: [15.844776779999961, 7.9223883899999805, 0.17605307533333292, 1.8424159046511586, 0.1173687168888886] (days)
