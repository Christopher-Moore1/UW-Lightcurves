# %%
from astropy.table import Table
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
outpath='HAT-264-0000614.rlc.tfalc'
data=Table.read(outpath,format='ascii')
t=data['col2']
mag=data['col8']

# %%
plt.figure(figsize=(20,8))
plt.plot(t,mag,'yo',markersize=10,label='HAT-264-0000614')
plt.ylabel('Relative Magnitude')
plt.xlabel('time (BJD-2454833)')
# Out:
# Text(0.5, 0, 'time (BJD-2454833)')

# %%
import astrobase
from astrobase import periodbase, checkplot
periodbase.use_astropy_bls()
# Out:
# [I 200817 13:45:08 __init__:84] An Astropy implementation of BLS is available because Astropy >= 3.1.
# [I 200817 13:45:08 __init__:86] If you want to use it as the default periodbase BLS runner, call the periodbase.use_astropy_bls() function.

# %%
dates=data['col2']
fluxes=data['col8']
errs=fluxes*0.01

# %%
glsp = periodbase.pgen_lsp(dates,fluxes,errs)
# Out:
# [I 200817 13:45:12 zgls:597] using autofreq with 1580 frequency points, start P = 0.100, end P = 31.690
# [I 200817 13:45:12 zgls:607] using 6 workers...

# %%
cp = checkplot.checkplot_png(glsp, dates, fluxes, errs)
# Out:
# [I 200817 13:46:50 nonphysical:216] spline fit done. nknots = 13,  chisq = 12661503.92741, reduced chisq = 9365.01770
# [I 200817 13:46:50 png:696] plotting phased LC with period 0.138989, epoch 1940.47756
# [I 200817 13:46:50 nonphysical:216] spline fit done. nknots = 13,  chisq = 13127341.95872, reduced chisq = 9709.57245
# [I 200817 13:46:50 png:696] plotting phased LC with period 0.069495, epoch 1940.47756
# [I 200817 13:46:50 nonphysical:216] spline fit done. nknots = 13,  chisq = 12474446.43088, reduced chisq = 9226.66156
# [I 200817 13:46:50 png:696] plotting phased LC with period 0.277979, epoch 1954.65710
# [I 200817 13:46:50 nonphysical:216] spline fit done. nknots = 13,  chisq = 12699260.00107, reduced chisq = 9392.94379
# [I 200817 13:46:50 png:696] plotting phased LC with period 0.182965, epoch 1960.21452
# [I 200817 13:46:50 nonphysical:216] spline fit done. nknots = 13,  chisq = 12733885.82286, reduced chisq = 9418.55460
# [I 200817 13:46:50 png:696] plotting phased LC with period 0.288612, epoch 1946.87265
# [I 200817 13:46:50 nonphysical:216] spline fit done. nknots = 13,  chisq = 12414550.09579, reduced chisq = 9182.35954
# [I 200817 13:46:50 png:696] plotting phased LC with period 7.545135, epoch 1970.65517
# [I 200817 13:46:50 nonphysical:216] spline fit done. nknots = 13,  chisq = 12848669.02531, reduced chisq = 9503.45342
# [I 200817 13:46:50 png:696] plotting phased LC with period 0.580395, epoch 1948.01682
# [I 200817 13:46:51 png:1233] checkplot done -> checkplot.png

# %%
from IPython.display import Image
Image('0000614-checkplot-glsp.png')

# %%
glsp
# Out:
# {'bestperiod': 0.13898932271929781,
#  'bestlspval': 0.031048238644277106,
#  'nbestpeaks': 5,
#  'nbestlspvals': [0.031048238644277106,
#   0.021874664454699367,
#   0.019676129942211382,
#   0.0189060815218465,
#   0.016156433685471167],
#  'nbestperiods': [0.13898932271929781,
#   0.18296515923787474,
#   0.2886117083788698,
#   7.545134661904739,
#   0.5803949739926723],
#  'lspvals': array([0.00263006, 0.00559062, 0.00649135, ..., 0.00108581, 0.00254465,
#         0.00391304]),
#  'omegas': array([ 0.198273  ,  0.2379276 ,  0.2775822 , ..., 62.73357791,
#         62.77323251, 62.81288711]),
#  'periods': array([31.68956558, 26.40797132, 22.63540399, ...,  0.10015665,
#          0.10009338,  0.10003019]),
#  'method': 'gls',
#  'kwargs': {'startp': None,
#   'endp': None,
#   'stepsize': 0.0001,
#   'autofreq': True,
#   'periodepsilon': 0.1,
#   'nbestpeaks': 5,
#   'sigclip': 10.0}}

# %%
print('LS algorithm:',(glsp['nbestperiods']),'(days)')
# Out:
# LS algorithm: [0.13898932271929781, 0.18296515923787474, 0.2886117083788698, 7.545134661904739, 0.5803949739926723] (days)

# %%
bls=periodbase.bls_parallel_pfind(dates,fluxes,errs)
# Out:
# [I 200817 13:47:55 abls:919] min P: 0.1, max P: 100.0, nfreq: 126632, minfreq: 0.01, maxfreq: 10.0
# [I 200817 13:47:55 abls:922] autofreq = True: using AUTOMATIC values for freq stepsize: 7.889032096980886e-05, ndurations: 100, min transit duration: 0.01, max transit duration: 0.4
# [W 200817 13:47:55 abls:964] the requested max P = 100.000 is larger than the time base of the observations = 31.690,  will make minfreq = 2 x 1/timebase
# [W 200817 13:47:55 abls:969] new minfreq: 0.0631122567758471, maxfreq: 10.0
# [I 200817 13:47:55 abls:980] using 6 workers...
# [I 200817 13:47:55 abls:1090] worker 1: minfreq = 0.063112, nfreqs = 21105
# [I 200817 13:47:55 abls:1090] worker 2: minfreq = 1.728092, nfreqs = 21105
# [I 200817 13:47:55 abls:1090] worker 3: minfreq = 3.393073, nfreqs = 21105
# [I 200817 13:47:55 abls:1090] worker 4: minfreq = 5.058053, nfreqs = 21105
# [I 200817 13:47:55 abls:1090] worker 5: minfreq = 6.723033, nfreqs = 21105
# [I 200817 13:47:55 abls:1090] worker 6: minfreq = 8.388013, nfreqs = 21107
# [I 200817 13:47:55 abls:1092] running...
# [E 200817 13:48:07 abls:1125] no finite periodogram values for this mag series, skipping...

# %%
cp = checkplot.checkplot_png(bls, dates, fluxes, errs)
# Out:
# [W 200817 13:48:28 png:1142] no best period found for this object, skipping...

# %%
spdm = periodbase.stellingwerf_pdm(dates,fluxes,errs)
# Out:
# [I 200817 13:48:33 spdm:337] using autofreq with 1580 frequency points, start P = 0.100, end P = 31.690
# [I 200817 13:48:33 spdm:349] using 6 workers...

# %%
cp = checkplot.checkplot_png(spdm, dates, fluxes, errs)
# Out:
# [I 200817 13:48:40 nonphysical:216] spline fit done. nknots = 13,  chisq = 13013036.24522, reduced chisq = 9625.02681
# [I 200817 13:48:40 png:696] plotting phased LC with period 8.802657, epoch 1958.00790
# [I 200817 13:48:41 nonphysical:216] spline fit done. nknots = 13,  chisq = 12644496.71193, reduced chisq = 9352.43840
# [I 200817 13:48:41 png:696] plotting phased LC with period 4.401329, epoch 1962.48244
# [I 200817 13:48:41 nonphysical:216] spline fit done. nknots = 13,  chisq = 12793038.85301, reduced chisq = 9462.30684
# [I 200817 13:48:41 png:696] plotting phased LC with period 17.605314, epoch 1953.65595
# [I 200817 13:48:41 nonphysical:216] spline fit done. nknots = 13,  chisq = 12758808.78496, reduced chisq = 9436.98875
# [I 200817 13:48:41 png:696] plotting phased LC with period 12.188294, epoch 1962.76849
# [I 200817 13:48:41 nonphysical:216] spline fit done. nknots = 13,  chisq = 12908274.19513, reduced chisq = 9547.54009
# [I 200817 13:48:41 png:696] plotting phased LC with period 2.475747, epoch 1967.69255
# [I 200817 13:48:41 nonphysical:216] spline fit done. nknots = 13,  chisq = 12679999.40488, reduced chisq = 9378.69778
# [I 200817 13:48:41 png:696] plotting phased LC with period 6.601993, epoch 1951.75581
# [I 200817 13:48:41 nonphysical:216] spline fit done. nknots = 13,  chisq = 12585324.59067, reduced chisq = 9308.67203
# [I 200817 13:48:41 png:696] plotting phased LC with period 15.844783, epoch 1950.50948
# [I 200817 13:48:42 png:1233] checkplot done -> checkplot.png

# %%
Image('0000614-checkplot-spdm.png')

# %%
print('PDM algorithm:',(spdm['nbestperiods']),'(days)')
# Out:
# PDM algorithm: [8.802657105555529, 12.188294453846117, 2.475747310937493, 6.601992829166647, 15.844782789999952] (days)
