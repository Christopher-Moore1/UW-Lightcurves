# %%
from astropy.table import Table
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
outpath='HAT-264-0001383.rlc.tfalc'
data=Table.read(outpath,format='ascii')
t=data['col2']
mag=data['col8']

# %%
plt.figure(figsize=(20,8))
plt.plot(t,mag,'yo',markersize=10,label='HAT-264-0001383')
plt.ylabel('Relative Magnitude')
plt.xlabel('time (BJD-2454833)')
# Out:
# Text(0.5, 0, 'time (BJD-2454833)')

# %%
import astrobase
from astrobase import periodbase, checkplot
periodbase.use_astropy_bls()
# Out:
# [I 200908 17:36:19 __init__:84] An Astropy implementation of BLS is available because Astropy >= 3.1.
# [I 200908 17:36:19 __init__:86] If you want to use it as the default periodbase BLS runner, call the periodbase.use_astropy_bls() function.

# %%
dates=data['col2']
fluxes=data['col8']
errs=data['col4']

# %%
glsp = periodbase.pgen_lsp(dates,fluxes,errs)
# Out:
# [I 200908 17:36:40 zgls:597] using autofreq with 1580 frequency points, start P = 0.100, end P = 31.690
# [I 200908 17:36:40 zgls:607] using 6 workers...

# %%
cp = checkplot.checkplot_png(glsp, dates, fluxes, errs)
# Out:
# [I 200908 17:36:45 nonphysical:216] spline fit done. nknots = 13,  chisq = 900.84267, reduced chisq = 0.65421
# [I 200908 17:36:45 png:696] plotting phased LC with period 31.689566, epoch 1950.36646
# [I 200908 17:36:45 nonphysical:216] spline fit done. nknots = 13,  chisq = 1023.28061, reduced chisq = 0.74312
# [I 200908 17:36:45 png:696] plotting phased LC with period 15.844783, epoch 1972.14669
# [I 200908 17:36:45 nonphysical:216] spline fit done. nknots = 13,  chisq = 899.89346, reduced chisq = 0.65352
# [I 200908 17:36:45 png:696] plotting phased LC with period 63.379131, epoch 1949.97826
# [I 200908 17:36:45 nonphysical:216] spline fit done. nknots = 13,  chisq = 900.67249, reduced chisq = 0.65408
# [I 200908 17:36:45 png:696] plotting phased LC with period 26.407971, epoch 1957.84444
# [I 200908 17:36:45 nonphysical:216] spline fit done. nknots = 13,  chisq = 950.72273, reduced chisq = 0.69043
# [I 200908 17:36:45 png:696] plotting phased LC with period 22.635404, epoch 1957.74228
# [I 200908 17:36:45 nonphysical:216] spline fit done. nknots = 13,  chisq = 991.52036, reduced chisq = 0.72006
# [I 200908 17:36:45 png:696] plotting phased LC with period 19.805978, epoch 1958.41653
# [I 200908 17:36:45 nonphysical:216] spline fit done. nknots = 13,  chisq = 993.04035, reduced chisq = 0.72116
# [I 200908 17:36:45 png:696] plotting phased LC with period 12.188294, epoch 1961.13395
# [I 200908 17:36:46 png:1233] checkplot done -> checkplot.png

# %%
from IPython.display import Image
Image('checkplot.png')

# %%
glsp
# Out:
# {'bestperiod': 31.689565579999904,
#  'bestlspval': 0.10338604435489626,
#  'nbestpeaks': 5,
#  'nbestlspvals': [0.10338604435489626,
#   0.09445939506189945,
#   0.06589147951221012,
#   0.0321400835527898,
#   0.020692949698933063],
#  'nbestperiods': [31.689565579999904,
#   26.407971316666586,
#   22.635403985714216,
#   19.805978487499942,
#   12.188294453846117],
#  'lspvals': array([1.03386044e-01, 9.44593951e-02, 6.58914795e-02, ...,
#         3.10706619e-04, 2.62600239e-05, 9.25303898e-06]),
#  'omegas': array([ 0.198273  ,  0.2379276 ,  0.2775822 , ..., 62.73357791,
#         62.77323251, 62.81288711]),
#  'periods': array([31.68956558, 26.40797132, 22.63540399, ...,  0.10015665,
#          0.10009338,  0.10003019]),
#  'method': 'gls',
#  'kwargs': {'startp': None,
#   'endp': None,
#   'stepsize': 0.0001,
#   'autofreq': True,
#   'periodepsilon': 0.1,
#   'nbestpeaks': 5,
#   'sigclip': 10.0}}

# %%
print('LS algorithm:',(glsp['nbestperiods']),'(days)')
# Out:
# LS algorithm: [31.689565579999904, 26.407971316666586, 22.635403985714216, 19.805978487499942, 12.188294453846117] (days)

# %%
bls=periodbase.bls_parallel_pfind(dates,fluxes,errs,startp=0.1,endp=30)
# Out:
# [I 200908 17:38:24 abls:919] min P: 0.1, max P: 30, nfreq: 126336, minfreq: 0.03333333333333333, maxfreq: 10.0
# [I 200908 17:38:24 abls:922] autofreq = True: using AUTOMATIC values for freq stepsize: 7.889032096980886e-05, ndurations: 100, min transit duration: 0.01, max transit duration: 0.4
# [I 200908 17:38:24 abls:980] using 6 workers...
# [I 200908 17:38:24 abls:1090] worker 1: minfreq = 0.033333, nfreqs = 21056
# [I 200908 17:38:24 abls:1090] worker 2: minfreq = 1.694448, nfreqs = 21056
# [I 200908 17:38:24 abls:1090] worker 3: minfreq = 3.355563, nfreqs = 21056
# [I 200908 17:38:24 abls:1090] worker 4: minfreq = 5.016677, nfreqs = 21056
# [I 200908 17:38:24 abls:1090] worker 5: minfreq = 6.677792, nfreqs = 21056
# [I 200908 17:38:24 abls:1090] worker 6: minfreq = 8.338906, nfreqs = 21056
# [I 200908 17:38:24 abls:1092] running...

# %%
cp = checkplot.checkplot_png(bls, dates, fluxes, errs)
# Out:
# [I 200908 17:38:50 nonphysical:216] spline fit done. nknots = 13,  chisq = 963.78017, reduced chisq = 0.69991
# [I 200908 17:38:50 png:696] plotting phased LC with period 0.102127, epoch 1952.32789
# [I 200908 17:38:50 nonphysical:216] spline fit done. nknots = 13,  chisq = 944.78150, reduced chisq = 0.68612
# [I 200908 17:38:50 png:696] plotting phased LC with period 0.051063, epoch 1951.69451
# [I 200908 17:38:50 nonphysical:216] spline fit done. nknots = 13,  chisq = 1042.95276, reduced chisq = 0.75741
# [I 200908 17:38:50 png:696] plotting phased LC with period 0.204254, epoch 1945.38114
# [I 200908 17:38:50 nonphysical:216] spline fit done. nknots = 13,  chisq = 976.15923, reduced chisq = 0.70890
# [I 200908 17:38:50 png:696] plotting phased LC with period 19.545548, epoch 1958.08962
# [I 200908 17:38:50 nonphysical:216] spline fit done. nknots = 13,  chisq = 896.39304, reduced chisq = 0.65098
# [I 200908 17:38:50 png:696] plotting phased LC with period 26.433990, epoch 1957.88531
# [I 200908 17:38:50 nonphysical:216] spline fit done. nknots = 13,  chisq = 1027.16439, reduced chisq = 0.74594
# [I 200908 17:38:50 png:696] plotting phased LC with period 0.398291, epoch 1950.03955
# [I 200908 17:38:50 nonphysical:216] spline fit done. nknots = 13,  chisq = 1014.74387, reduced chisq = 0.73692
# [I 200908 17:38:50 png:696] plotting phased LC with period 15.524065, epoch 1955.98516
# [I 200908 17:38:51 png:1233] checkplot done -> checkplot.png

# %%
Image('0001383-checkplot-bls.png')

# %%
spdm = periodbase.stellingwerf_pdm(dates,fluxes,errs)
# Out:
# [I 200908 17:39:33 spdm:337] using autofreq with 1580 frequency points, start P = 0.100, end P = 31.690
# [I 200908 17:39:33 spdm:349] using 6 workers...

# %%
cp = checkplot.checkplot_png(spdm, dates, fluxes, errs)
# Out:
# [I 200908 17:39:49 nonphysical:216] spline fit done. nknots = 13,  chisq = 900.84267, reduced chisq = 0.65421
# [I 200908 17:39:49 png:696] plotting phased LC with period 31.689566, epoch 1950.36646
# [I 200908 17:39:49 nonphysical:216] spline fit done. nknots = 13,  chisq = 1023.28061, reduced chisq = 0.74312
# [I 200908 17:39:49 png:696] plotting phased LC with period 15.844783, epoch 1972.14669
# [I 200908 17:39:49 nonphysical:216] spline fit done. nknots = 13,  chisq = 899.89346, reduced chisq = 0.65352
# [I 200908 17:39:49 png:696] plotting phased LC with period 63.379131, epoch 1949.97826
# [I 200908 17:39:49 nonphysical:216] spline fit done. nknots = 13,  chisq = 900.67249, reduced chisq = 0.65408
# [I 200908 17:39:49 png:696] plotting phased LC with period 26.407971, epoch 1957.84444
# [I 200908 17:39:49 nonphysical:216] spline fit done. nknots = 13,  chisq = 950.72273, reduced chisq = 0.69043
# [I 200908 17:39:49 png:696] plotting phased LC with period 22.635404, epoch 1957.74228
# [I 200908 17:39:49 nonphysical:216] spline fit done. nknots = 13,  chisq = 939.82590, reduced chisq = 0.68252
# [I 200908 17:39:49 png:696] plotting phased LC with period 0.102224, epoch 1951.14286
# [I 200908 17:39:49 nonphysical:216] spline fit done. nknots = 13,  chisq = 991.52036, reduced chisq = 0.72006
# [I 200908 17:39:49 png:696] plotting phased LC with period 19.805978, epoch 1958.41653
# [I 200908 17:39:50 png:1233] checkplot done -> checkplot.png

# %%
Image('0001383-checkplot-spdm.png')

# %%
print('PDM algorithm:',(spdm['nbestperiods']),'(days)')
# Out:
# PDM algorithm: [31.689565579999904, 26.40797131666659, 22.635403985714216, 0.10222440509677387, 19.805978487499942] (days)
