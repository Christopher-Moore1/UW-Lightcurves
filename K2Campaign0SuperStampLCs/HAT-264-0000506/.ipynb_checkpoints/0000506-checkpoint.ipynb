# %%
from astropy.table import Table
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
outpath='HAT-264-0000506.rlc.tfalc'
data=Table.read(outpath,format='ascii')
t=data['col2']
mag=data['col8']

# %%
plt.figure(figsize=(20,8))
plt.plot(t,mag,'yo',markersize=10,label='HAT-264-0000506')
plt.ylabel('Relative Magnitude')
plt.xlabel('time (BJD-2454833)')
# Out:
# Text(0.5, 0, 'time (BJD-2454833)')

# %%
import astrobase
from astrobase import periodbase, checkplot
periodbase.use_astropy_bls()
# Out:
# [I 200815 13:50:55 __init__:84] An Astropy implementation of BLS is available because Astropy >= 3.1.
# [I 200815 13:50:55 __init__:86] If you want to use it as the default periodbase BLS runner, call the periodbase.use_astropy_bls() function.

# %%
dates=data['col2']
fluxes=data['col8']
errs=fluxes*0.01

# %%
glsp = periodbase.pgen_lsp(dates,fluxes,errs)
# Out:
# [I 200815 13:50:57 zgls:597] using autofreq with 1580 frequency points, start P = 0.100, end P = 31.690
# [I 200815 13:50:57 zgls:607] using 6 workers...

# %%
cp = checkplot.checkplot_png(glsp, dates, fluxes, errs)
# Out:
# [I 200815 13:51:01 nonphysical:216] spline fit done. nknots = 13,  chisq = 13407062.76178, reduced chisq = 9887.21443
# [I 200815 13:51:01 png:696] plotting phased LC with period 0.498263, epoch 1940.47762
# [I 200815 13:51:01 nonphysical:216] spline fit done. nknots = 13,  chisq = 13430930.30066, reduced chisq = 9904.81586
# [I 200815 13:51:01 png:696] plotting phased LC with period 0.249132, epoch 1971.49293
# [I 200815 13:51:01 nonphysical:216] spline fit done. nknots = 13,  chisq = 13329327.75754, reduced chisq = 9829.88773
# [I 200815 13:51:01 png:696] plotting phased LC with period 0.996527, epoch 1940.47762
# [I 200815 13:51:01 nonphysical:216] spline fit done. nknots = 13,  chisq = 13434363.27216, reduced chisq = 9907.34755
# [I 200815 13:51:01 png:696] plotting phased LC with period 0.235086, epoch 1940.47762
# [I 200815 13:51:01 nonphysical:216] spline fit done. nknots = 13,  chisq = 13332466.51510, reduced chisq = 9832.20244
# [I 200815 13:51:01 png:696] plotting phased LC with period 0.153386, epoch 1940.47762
# [I 200815 13:51:01 nonphysical:216] spline fit done. nknots = 13,  chisq = 13389893.66823, reduced chisq = 9874.55285
# [I 200815 13:51:01 png:696] plotting phased LC with period 0.276523, epoch 1950.79558
# [I 200815 13:51:01 nonphysical:216] spline fit done. nknots = 13,  chisq = 13342827.13994, reduced chisq = 9847.10490
# [I 200815 13:51:01 png:696] plotting phased LC with period 0.110803, epoch 1969.28629
# [I 200815 13:51:02 png:1233] checkplot done -> checkplot.png

# %%
from IPython.display import Image
Image('0000506-checkplot-glsp.png')

# %%
glsp
# Out:
# {'bestperiod': 0.49826347720125674,
#  'bestlspval': 0.008739444341241588,
#  'nbestpeaks': 5,
#  'nbestlspvals': [0.008739444341241588,
#   0.008229565242034984,
#   0.00812816348059131,
#   0.007897206234452723,
#   0.007882417048137266],
#  'nbestperiods': [0.49826347720125674,
#   0.23508573553412407,
#   0.15338604622458824,
#   0.27652318630017386,
#   0.11080264737762213],
#  'lspvals': array([0.00048792, 0.00066621, 0.0010405 , ..., 0.00328145, 0.00287511,
#         0.00208555]),
#  'omegas': array([ 0.19827305,  0.23792767,  0.27758228, ..., 62.7335946 ,
#         62.77324921, 62.81290382]),
#  'periods': array([31.68955715, 26.40796429, 22.63539796, ...,  0.10015663,
#          0.10009336,  0.10003017]),
#  'method': 'gls',
#  'kwargs': {'startp': None,
#   'endp': None,
#   'stepsize': 0.0001,
#   'autofreq': True,
#   'periodepsilon': 0.1,
#   'nbestpeaks': 5,
#   'sigclip': 10.0}}

# %%
print('LS algorithm:',(glsp['nbestperiods']),'(days)')
# Out:
# LS algorithm: [0.49826347720125674, 0.23508573553412407, 0.15338604622458824, 0.27652318630017386, 0.11080264737762213] (days)

# %%
bls=periodbase.bls_parallel_pfind(dates,fluxes,errs)
# Out:
# [I 200815 13:51:36 abls:919] min P: 0.1, max P: 100.0, nfreq: 126632, minfreq: 0.01, maxfreq: 10.0
# [I 200815 13:51:36 abls:922] autofreq = True: using AUTOMATIC values for freq stepsize: 7.889034195607261e-05, ndurations: 100, min transit duration: 0.01, max transit duration: 0.4
# [W 200815 13:51:36 abls:964] the requested max P = 100.000 is larger than the time base of the observations = 31.690,  will make minfreq = 2 x 1/timebase
# [W 200815 13:51:36 abls:969] new minfreq: 0.06311227356485809, maxfreq: 10.0
# [I 200815 13:51:36 abls:980] using 6 workers...
# [I 200815 13:51:36 abls:1090] worker 1: minfreq = 0.063112, nfreqs = 21105
# [I 200815 13:51:36 abls:1090] worker 2: minfreq = 1.728093, nfreqs = 21105
# [I 200815 13:51:36 abls:1090] worker 3: minfreq = 3.393074, nfreqs = 21105
# [I 200815 13:51:36 abls:1090] worker 4: minfreq = 5.058054, nfreqs = 21105
# [I 200815 13:51:36 abls:1090] worker 5: minfreq = 6.723035, nfreqs = 21105
# [I 200815 13:51:36 abls:1090] worker 6: minfreq = 8.388016, nfreqs = 21107
# [I 200815 13:51:36 abls:1092] running...
# [E 200815 13:51:48 abls:1125] no finite periodogram values for this mag series, skipping...

# %%
cp = checkplot.checkplot_png(bls, dates, fluxes, errs)
# Out:
# [W 200815 13:51:49 png:1142] no best period found for this object, skipping...

# %%
spdm = periodbase.stellingwerf_pdm(dates,fluxes,errs)
# Out:
# [I 200815 13:51:56 spdm:337] using autofreq with 1580 frequency points, start P = 0.100, end P = 31.690
# [I 200815 13:51:56 spdm:349] using 6 workers...

# %%
cp = checkplot.checkplot_png(spdm, dates, fluxes, errs)
# Out:
# [I 200815 13:52:02 nonphysical:216] spline fit done. nknots = 13,  chisq = 13511120.16172, reduced chisq = 9963.95292
# [I 200815 13:52:02 png:696] plotting phased LC with period 19.805973, epoch 1960.27588
# [I 200815 13:52:02 nonphysical:216] spline fit done. nknots = 13,  chisq = 13455063.20938, reduced chisq = 9922.61299
# [I 200815 13:52:02 png:696] plotting phased LC with period 9.902987, epoch 1970.18529
# [I 200815 13:52:02 nonphysical:216] spline fit done. nknots = 13,  chisq = 13440939.07026, reduced chisq = 9912.19695
# [I 200815 13:52:02 png:696] plotting phased LC with period 39.611946, epoch 1972.16718
# [I 200815 13:52:02 nonphysical:216] spline fit done. nknots = 13,  chisq = 13381218.41618, reduced chisq = 9868.15517
# [I 200815 13:52:02 png:696] plotting phased LC with period 13.203982, epoch 1953.67644
# [I 200815 13:52:02 nonphysical:216] spline fit done. nknots = 13,  chisq = 13439411.96010, reduced chisq = 9918.38521
# [I 200815 13:52:02 png:696] plotting phased LC with period 15.844779, epoch 1956.29170
# [I 200815 13:52:02 nonphysical:216] spline fit done. nknots = 13,  chisq = 13423073.44913, reduced chisq = 9899.02172
# [I 200815 13:52:02 png:696] plotting phased LC with period 6.601991, epoch 1947.07703
# [I 200815 13:52:02 nonphysical:216] spline fit done. nknots = 13,  chisq = 13527568.24267, reduced chisq = 9976.08277
# [I 200815 13:52:02 png:696] plotting phased LC with period 8.802655, epoch 1940.51848
# [I 200815 13:52:03 png:1233] checkplot done -> checkplot.png

# %%
Image('0000506-checkplot-spdm.png')

# %%
print('PDM algorithm:',(spdm['nbestperiods']),'(days)')
# Out:
# PDM algorithm: [19.805973218749955, 13.203982145833303, 15.844778574999964, 6.601991072916651, 8.802654763888867] (days)
