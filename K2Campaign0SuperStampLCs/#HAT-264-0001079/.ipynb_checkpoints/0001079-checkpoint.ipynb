# %%
from astropy.table import Table
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
outpath='HAT-264-0001079.rlc.tfalc'
data=Table.read(outpath,format='ascii')
t=data['col2']
mag=data['col8']

# %%
plt.figure(figsize=(20,8))
plt.plot(t,mag,'yo',markersize=10,label='HAT-264-0001079')
plt.ylabel('Relative Magnitude')
plt.xlabel('time (BJD-2454833)')
# Out:
# Text(0.5, 0, 'time (BJD-2454833)')

# %%
import astrobase
from astrobase import periodbase, checkplot
periodbase.use_astropy_bls()
# Out:
# [I 200819 11:20:57 __init__:84] An Astropy implementation of BLS is available because Astropy >= 3.1.
# [I 200819 11:20:57 __init__:86] If you want to use it as the default periodbase BLS runner, call the periodbase.use_astropy_bls() function.

# %%
dates=data['col2']
fluxes=data['col8']
errs=fluxes*0.01

# %%
glsp = periodbase.pgen_lsp(dates,fluxes,errs)
# Out:
# [I 200819 11:21:00 zgls:597] using autofreq with 1580 frequency points, start P = 0.100, end P = 31.690
# [I 200819 11:21:00 zgls:607] using 6 workers...

# %%
cp = checkplot.checkplot_png(glsp, dates, fluxes, errs)
# Out:
# [I 200819 11:21:03 nonphysical:216] spline fit done. nknots = 13,  chisq = 13184871.07660, reduced chisq = 9854.16373
# [I 200819 11:21:03 png:696] plotting phased LC with period 0.136358, epoch 1940.47761
# [I 200819 11:21:03 nonphysical:216] spline fit done. nknots = 13,  chisq = 13196258.74379, reduced chisq = 9862.67470
# [I 200819 11:21:03 png:696] plotting phased LC with period 0.068179, epoch 1953.63557
# [I 200819 11:21:03 nonphysical:216] spline fit done. nknots = 13,  chisq = 13095343.84678, reduced chisq = 9787.25250
# [I 200819 11:21:03 png:696] plotting phased LC with period 0.272716, epoch 1943.13372
# [I 200819 11:21:03 nonphysical:216] spline fit done. nknots = 13,  chisq = 13179881.49829, reduced chisq = 9857.80217
# [I 200819 11:21:03 png:696] plotting phased LC with period 0.119134, epoch 1940.47761
# [I 200819 11:21:03 nonphysical:216] spline fit done. nknots = 13,  chisq = 13202425.52038, reduced chisq = 9867.28365
# [I 200819 11:21:03 png:696] plotting phased LC with period 0.318808, epoch 1940.47761
# [I 200819 11:21:03 nonphysical:216] spline fit done. nknots = 13,  chisq = 13095320.86838, reduced chisq = 9787.23533
# [I 200819 11:21:03 png:696] plotting phased LC with period 0.271315, epoch 1962.72767
# [I 200819 11:21:03 nonphysical:216] spline fit done. nknots = 13,  chisq = 13147170.38480, reduced chisq = 9825.98683
# [I 200819 11:21:03 png:696] plotting phased LC with period 1.063408, epoch 1940.47761
# [I 200819 11:21:04 png:1233] checkplot done -> checkplot.png

# %%
from IPython.display import Image
Image('0001079-checkplot-glsp.png')

# %%
glsp
# Out:
# {'bestperiod': 0.13635782577452582,
#  'bestlspval': 0.01087839908402627,
#  'nbestpeaks': 5,
#  'nbestlspvals': [0.01087839908402627,
#   0.01084633864851621,
#   0.010038211534852475,
#   0.008642818188226632,
#   0.0076376969369512035],
#  'nbestperiods': [0.13635782577452582,
#   0.1191336793609015,
#   0.3188084377263562,
#   0.271314714982875,
#   1.0634080104026777],
#  'lspvals': array([3.23752531e-03, 4.06975394e-03, 4.01682541e-03, ...,
#         5.58031947e-04, 3.42856107e-06, 3.55410522e-04]),
#  'omegas': array([ 0.19827305,  0.23792765,  0.27758226, ..., 62.73359151,
#         62.77324612, 62.81290073]),
#  'periods': array([31.68955871, 26.40796559, 22.63539908, ...,  0.10015663,
#          0.10009336,  0.10003017]),
#  'method': 'gls',
#  'kwargs': {'startp': None,
#   'endp': None,
#   'stepsize': 0.0001,
#   'autofreq': True,
#   'periodepsilon': 0.1,
#   'nbestpeaks': 5,
#   'sigclip': 10.0}}

# %%
print('LS algorithm:',(glsp['nbestperiods']),'(days)')
# Out:
# LS algorithm: [0.13635782577452582, 0.1191336793609015, 0.3188084377263562, 0.271314714982875, 1.0634080104026777] (days)

# %%
bls=periodbase.bls_parallel_pfind(dates,fluxes,errs)
# Out:
# [I 200819 11:21:39 abls:919] min P: 0.1, max P: 100.0, nfreq: 126632, minfreq: 0.01, maxfreq: 10.0
# [I 200819 11:21:39 abls:922] autofreq = True: using AUTOMATIC values for freq stepsize: 7.889033807249301e-05, ndurations: 100, min transit duration: 0.01, max transit duration: 0.4
# [W 200819 11:21:39 abls:964] the requested max P = 100.000 is larger than the time base of the observations = 31.690,  will make minfreq = 2 x 1/timebase
# [W 200819 11:21:39 abls:969] new minfreq: 0.06311227045799442, maxfreq: 10.0
# [I 200819 11:21:39 abls:980] using 6 workers...
# [I 200819 11:21:39 abls:1090] worker 1: minfreq = 0.063112, nfreqs = 21105
# [I 200819 11:21:39 abls:1090] worker 2: minfreq = 1.728093, nfreqs = 21105
# [I 200819 11:21:39 abls:1090] worker 3: minfreq = 3.393073, nfreqs = 21105
# [I 200819 11:21:39 abls:1090] worker 4: minfreq = 5.058054, nfreqs = 21105
# [I 200819 11:21:39 abls:1090] worker 5: minfreq = 6.723035, nfreqs = 21105
# [I 200819 11:21:39 abls:1090] worker 6: minfreq = 8.388015, nfreqs = 21107
# [I 200819 11:21:39 abls:1092] running...
# [E 200819 11:21:51 abls:1125] no finite periodogram values for this mag series, skipping...

# %%
cp = checkplot.checkplot_png(bls, dates, fluxes, errs)
# Out:
# [W 200819 11:21:51 png:1142] no best period found for this object, skipping...

# %%
spdm = periodbase.stellingwerf_pdm(dates,fluxes,errs)
# Out:
# [I 200819 11:22:03 spdm:337] using autofreq with 1580 frequency points, start P = 0.100, end P = 31.690
# [I 200819 11:22:03 spdm:349] using 6 workers...

# %%
cp = checkplot.checkplot_png(spdm, dates, fluxes, errs)
# Out:
# [I 200819 11:22:06 nonphysical:216] spline fit done. nknots = 13,  chisq = 13187370.26960, reduced chisq = 9863.40334
# [I 200819 11:22:06 png:696] plotting phased LC with period 5.281593, epoch 1961.60393
# [I 200819 11:22:06 nonphysical:216] spline fit done. nknots = 13,  chisq = 13205758.54120, reduced chisq = 9877.15672
# [I 200819 11:22:06 png:696] plotting phased LC with period 2.640797, epoch 1940.47761
# [I 200819 11:22:06 nonphysical:216] spline fit done. nknots = 13,  chisq = 13266581.79556, reduced chisq = 9922.64906
# [I 200819 11:22:06 png:696] plotting phased LC with period 10.563186, epoch 1961.60393
# [I 200819 11:22:06 nonphysical:216] spline fit done. nknots = 13,  chisq = 13280535.25739, reduced chisq = 9925.66163
# [I 200819 11:22:06 png:696] plotting phased LC with period 2.685556, epoch 1959.27471
# [I 200819 11:22:06 nonphysical:216] spline fit done. nknots = 13,  chisq = 13245833.18967, reduced chisq = 9899.72585
# [I 200819 11:22:06 png:696] plotting phased LC with period 7.922390, epoch 1940.47761
# [I 200819 11:22:06 nonphysical:216] spline fit done. nknots = 13,  chisq = 13259487.04299, reduced chisq = 9909.93053
# [I 200819 11:22:06 png:696] plotting phased LC with period 14.404345, epoch 1955.00449
# [I 200819 11:22:06 nonphysical:216] spline fit done. nknots = 13,  chisq = 13214234.32026, reduced chisq = 9876.10936
# [I 200819 11:22:06 png:696] plotting phased LC with period 4.801448, epoch 1956.88420
# [I 200819 11:22:07 png:1233] checkplot done -> checkplot.png

# %%
Image('0001079-checkplot-spdm.png')

# %%
print('PDM algorithm:',(spdm['nbestperiods']),'(days)')
# Out:
# PDM algorithm: [5.2815931183333005, 2.685555822881339, 7.922389677499949, 14.404344868181727, 4.8014482893939086] (days)
