# %%
from astropy.table import Table
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
outpath='HAT-264-0001266.rlc.tfalc'
data=Table.read(outpath,format='ascii')
t=data['col2']
mag=data['col8']

# %%
plt.figure(figsize=(20,8))
plt.plot(t,mag,'yo',markersize=10,label='HAT-264-0001266')
plt.ylabel('Relative Magnitude')
plt.xlabel('time (BJD-2454833)')
# Out:
# Text(0.5, 0, 'time (BJD-2454833)')

# %%
import astrobase
from astrobase import periodbase, checkplot
periodbase.use_astropy_bls()
# Out:
# [I 200819 11:54:14 __init__:84] An Astropy implementation of BLS is available because Astropy >= 3.1.
# [I 200819 11:54:14 __init__:86] If you want to use it as the default periodbase BLS runner, call the periodbase.use_astropy_bls() function.

# %%
dates=data['col2']
fluxes=data['col8']
errs=fluxes*0.01

# %%
glsp = periodbase.pgen_lsp(dates,fluxes,errs)
# Out:
# [I 200819 11:54:16 zgls:597] using autofreq with 1580 frequency points, start P = 0.100, end P = 31.690
# [I 200819 11:54:16 zgls:607] using 6 workers...

# %%
cp = checkplot.checkplot_png(glsp, dates, fluxes, errs)
# Out:
# [I 200819 11:54:19 nonphysical:216] spline fit done. nknots = 13,  chisq = 13217523.36805, reduced chisq = 9827.15492
# [I 200819 11:54:19 png:696] plotting phased LC with period 0.181290, epoch 1963.32022
# [I 200819 11:54:19 nonphysical:216] spline fit done. nknots = 13,  chisq = 13298639.19264, reduced chisq = 9887.46408
# [I 200819 11:54:19 png:696] plotting phased LC with period 0.090645, epoch 1940.47763
# [I 200819 11:54:19 nonphysical:216] spline fit done. nknots = 13,  chisq = 13331275.48811, reduced chisq = 9911.72899
# [I 200819 11:54:19 png:696] plotting phased LC with period 0.362581, epoch 1940.47763
# [I 200819 11:54:19 nonphysical:216] spline fit done. nknots = 13,  chisq = 13084913.24547, reduced chisq = 9728.56003
# [I 200819 11:54:19 png:696] plotting phased LC with period 0.149479, epoch 1940.47763
# [I 200819 11:54:19 nonphysical:216] spline fit done. nknots = 13,  chisq = 13334374.88742, reduced chisq = 9914.03337
# [I 200819 11:54:19 png:696] plotting phased LC with period 0.288612, epoch 1942.78640
# [I 200819 11:54:19 nonphysical:216] spline fit done. nknots = 13,  chisq = 13351220.99581, reduced chisq = 9926.55836
# [I 200819 11:54:19 png:696] plotting phased LC with period 0.206851, epoch 1957.02725
# [I 200819 11:54:19 nonphysical:216] spline fit done. nknots = 13,  chisq = 13324335.95710, reduced chisq = 9906.56948
# [I 200819 11:54:19 png:696] plotting phased LC with period 0.649376, epoch 1955.41315
# [I 200819 11:54:20 png:1233] checkplot done -> checkplot.png

# %%
from IPython.display import Image
Image('0001266-checkplot-glsp.png')

# %%
glsp
# Out:
# {'bestperiod': 0.18129036344393595,
#  'bestlspval': 0.011582040427039059,
#  'nbestpeaks': 5,
#  'nbestlspvals': [0.011582040427039059,
#   0.010948132407977708,
#   0.008808133905571785,
#   0.007581768753952459,
#   0.00671538346896491],
#  'nbestperiods': [0.18129036344393595,
#   0.14947903551886793,
#   0.2886116168488161,
#   0.20685088466057444,
#   0.6493761379098362],
#  'lspvals': array([0.00061966, 0.00060049, 0.00031465, ..., 0.00201902, 0.00095568,
#         0.00031424]),
#  'omegas': array([ 0.19827307,  0.23792768,  0.27758229, ..., 62.7335978 ,
#         62.77325242, 62.81290703]),
#  'periods': array([31.68955553, 26.40796294, 22.63539681, ...,  0.10015662,
#          0.10009335,  0.10003016]),
#  'method': 'gls',
#  'kwargs': {'startp': None,
#   'endp': None,
#   'stepsize': 0.0001,
#   'autofreq': True,
#   'periodepsilon': 0.1,
#   'nbestpeaks': 5,
#   'sigclip': 10.0}}

# %%
print('LS algorithm:',(glsp['nbestperiods']),'(days)')
# Out:
# LS algorithm: [0.18129036344393595, 0.14947903551886793, 0.2886116168488161, 0.20685088466057444, 0.6493761379098362] (days)

# %%
bls=periodbase.bls_parallel_pfind(dates,fluxes,errs)
# Out:
# [I 200819 11:54:55 abls:919] min P: 0.1, max P: 100.0, nfreq: 126632, minfreq: 0.01, maxfreq: 10.0
# [I 200819 11:54:55 abls:922] autofreq = True: using AUTOMATIC values for freq stepsize: 7.889034598902118e-05, ndurations: 100, min transit duration: 0.01, max transit duration: 0.4
# [W 200819 11:54:55 abls:964] the requested max P = 100.000 is larger than the time base of the observations = 31.690,  will make minfreq = 2 x 1/timebase
# [W 200819 11:54:55 abls:969] new minfreq: 0.06311227679121695, maxfreq: 10.0
# [I 200819 11:54:55 abls:980] using 6 workers...
# [I 200819 11:54:55 abls:1090] worker 1: minfreq = 0.063112, nfreqs = 21105
# [I 200819 11:54:55 abls:1090] worker 2: minfreq = 1.728093, nfreqs = 21105
# [I 200819 11:54:55 abls:1090] worker 3: minfreq = 3.393074, nfreqs = 21105
# [I 200819 11:54:55 abls:1090] worker 4: minfreq = 5.058055, nfreqs = 21105
# [I 200819 11:54:55 abls:1090] worker 5: minfreq = 6.723035, nfreqs = 21105
# [I 200819 11:54:55 abls:1090] worker 6: minfreq = 8.388016, nfreqs = 21107
# [I 200819 11:54:55 abls:1092] running...
# [E 200819 11:55:07 abls:1125] no finite periodogram values for this mag series, skipping...

# %%
cp = checkplot.checkplot_png(bls, dates, fluxes, errs)
# Out:
# [W 200819 11:55:07 png:1142] no best period found for this object, skipping...

# %%
spdm = periodbase.stellingwerf_pdm(dates,fluxes,errs)
# Out:
# [I 200819 11:55:10 spdm:337] using autofreq with 1580 frequency points, start P = 0.100, end P = 31.690
# [I 200819 11:55:10 spdm:349] using 6 workers...

# %%
cp = checkplot.checkplot_png(spdm, dates, fluxes, errs)
# Out:
# [I 200819 11:55:14 nonphysical:216] spline fit done. nknots = 13,  chisq = 13147044.26950, reduced chisq = 9774.75410
# [I 200819 11:55:14 png:696] plotting phased LC with period 0.149338, epoch 1948.69114
# [I 200819 11:55:14 nonphysical:216] spline fit done. nknots = 13,  chisq = 13414111.55099, reduced chisq = 9973.31714
# [I 200819 11:55:14 png:696] plotting phased LC with period 0.074669, epoch 1940.47763
# [I 200819 11:55:14 nonphysical:216] spline fit done. nknots = 13,  chisq = 13124943.98845, reduced chisq = 9758.32267
# [I 200819 11:55:14 png:696] plotting phased LC with period 0.298676, epoch 1956.90466
# [I 200819 11:55:14 nonphysical:216] spline fit done. nknots = 13,  chisq = 13263693.97530, reduced chisq = 9861.48251
# [I 200819 11:55:14 png:696] plotting phased LC with period 0.298395, epoch 1940.47763
# [I 200819 11:55:14 nonphysical:216] spline fit done. nknots = 13,  chisq = 13333399.26135, reduced chisq = 9913.30800
# [I 200819 11:55:14 png:696] plotting phased LC with period 0.447593, epoch 1954.80020
# [I 200819 11:55:14 nonphysical:216] spline fit done. nknots = 13,  chisq = 13340444.44065, reduced chisq = 9918.54605
# [I 200819 11:55:14 png:696] plotting phased LC with period 0.895185, epoch 1962.85029
# [I 200819 11:55:14 nonphysical:216] spline fit done. nknots = 13,  chisq = 13177207.37409, reduced chisq = 9797.18020
# [I 200819 11:55:14 png:696] plotting phased LC with period 0.747395, epoch 1954.67761
# [I 200819 11:55:15 png:1233] checkplot done -> checkplot.png

# %%
Image('0001266-checkplot-spdm.png')

# %%
print('PDM algorithm:',(spdm['nbestperiods']),'(days)')
# Out:
# PDM algorithm: [0.14933815047125354, 0.298395061487759, 0.4475925922316385, 0.895185184463277, 0.7473951775943397] (days)
