# %%
from astropy.table import Table
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
outpath='HAT-264-0001290.rlc.tfalc'
data=Table.read(outpath,format='ascii')
t=data['col2']
mag=data['col8']

# %%
plt.figure(figsize=(20,8))
plt.plot(t,mag,'yo',markersize=10,label='HAT-264-0001290')
plt.ylabel('Relative Magnitude')
plt.xlabel('time (BJD-2454833)')
# Out:
# Text(0.5, 0, 'time (BJD-2454833)')

# %%
import astrobase
from astrobase import periodbase, checkplot
periodbase.use_astropy_bls()
# Out:
# [I 200819 20:55:16 __init__:84] An Astropy implementation of BLS is available because Astropy >= 3.1.
# [I 200819 20:55:16 __init__:86] If you want to use it as the default periodbase BLS runner, call the periodbase.use_astropy_bls() function.

# %%
dates=data['col2']
fluxes=data['col8']
errs=data['col4']

# %%
glsp = periodbase.pgen_lsp(dates,fluxes,errs)
# Out:
# [I 200819 20:55:20 zgls:597] using autofreq with 1580 frequency points, start P = 0.100, end P = 31.690
# [I 200819 20:55:20 zgls:607] using 6 workers...

# %%
cp = checkplot.checkplot_png(glsp, dates, fluxes, errs)
# Out:
# [I 200819 20:55:23 nonphysical:216] spline fit done. nknots = 13,  chisq = 849.03442, reduced chisq = 0.62109
# [I 200819 20:55:23 png:696] plotting phased LC with period 0.736966, epoch 1972.16718
# [I 200819 20:55:23 nonphysical:216] spline fit done. nknots = 13,  chisq = 877.38666, reduced chisq = 0.64183
# [I 200819 20:55:23 png:696] plotting phased LC with period 0.368483, epoch 1940.47762
# [I 200819 20:55:23 nonphysical:216] spline fit done. nknots = 13,  chisq = 847.57091, reduced chisq = 0.62002
# [I 200819 20:55:23 png:696] plotting phased LC with period 1.473933, epoch 1962.58466
# [I 200819 20:55:23 nonphysical:216] spline fit done. nknots = 13,  chisq = 864.80040, reduced chisq = 0.63263
# [I 200819 20:55:23 png:696] plotting phased LC with period 0.101961, epoch 1955.00450
# [I 200819 20:55:23 nonphysical:216] spline fit done. nknots = 13,  chisq = 865.59033, reduced chisq = 0.63320
# [I 200819 20:55:23 png:696] plotting phased LC with period 0.174694, epoch 1940.47762
# [I 200819 20:55:23 nonphysical:216] spline fit done. nknots = 13,  chisq = 872.24941, reduced chisq = 0.63808
# [I 200819 20:55:23 png:696] plotting phased LC with period 0.246037, epoch 1940.47762
# [I 200819 20:55:23 nonphysical:216] spline fit done. nknots = 13,  chisq = 868.75052, reduced chisq = 0.63552
# [I 200819 20:55:23 png:696] plotting phased LC with period 0.132815, epoch 1940.47762
# [I 200819 20:55:24 png:1233] checkplot done -> checkplot.png

# %%
from IPython.display import Image
Image('0001290-checkplot-glsp.png')

# %%
glsp
# Out:
# {'bestperiod': 0.7369664453488356,
#  'bestlspval': 0.02835029519422461,
#  'nbestpeaks': 5,
#  'nbestlspvals': [0.02835029519422461,
#   0.014008595047667697,
#   0.013720096714065726,
#   0.010596424406727957,
#   0.009891815148910434],
#  'nbestperiods': [0.7369664453488356,
#   0.10196125209137685,
#   0.17469436135611868,
#   0.24603693439440938,
#   0.1328145731349536],
#  'lspvals': array([2.39255687e-04, 1.00095664e-04, 4.76254930e-05, ...,
#         3.31816853e-04, 6.71866962e-04, 1.00272723e-03]),
#  'omegas': array([ 0.19827305,  0.23792767,  0.27758228, ..., 62.7335946 ,
#         62.77324921, 62.81290382]),
#  'periods': array([31.68955715, 26.40796429, 22.63539796, ...,  0.10015663,
#          0.10009336,  0.10003017]),
#  'method': 'gls',
#  'kwargs': {'startp': None,
#   'endp': None,
#   'stepsize': 0.0001,
#   'autofreq': True,
#   'periodepsilon': 0.1,
#   'nbestpeaks': 5,
#   'sigclip': 10.0}}

# %%
print('LS algorithm:',(glsp['nbestperiods']),'(days)')
# Out:
# LS algorithm: [0.7369664453488356, 0.10196125209137685, 0.17469436135611868, 0.24603693439440938, 0.1328145731349536] (days)

# %%
bls=periodbase.bls_parallel_pfind(dates,fluxes,errs,startp=0.1,endp=30)
# Out:
# [I 200819 20:56:12 abls:919] min P: 0.1, max P: 30, nfreq: 126336, minfreq: 0.03333333333333333, maxfreq: 10.0
# [I 200819 20:56:12 abls:922] autofreq = True: using AUTOMATIC values for freq stepsize: 7.889034195607261e-05, ndurations: 100, min transit duration: 0.01, max transit duration: 0.4
# [I 200819 20:56:12 abls:980] using 6 workers...
# [I 200819 20:56:12 abls:1090] worker 1: minfreq = 0.033333, nfreqs = 21056
# [I 200819 20:56:12 abls:1090] worker 2: minfreq = 1.694448, nfreqs = 21056
# [I 200819 20:56:12 abls:1090] worker 3: minfreq = 3.355563, nfreqs = 21056
# [I 200819 20:56:12 abls:1090] worker 4: minfreq = 5.016678, nfreqs = 21056
# [I 200819 20:56:12 abls:1090] worker 5: minfreq = 6.677793, nfreqs = 21056
# [I 200819 20:56:12 abls:1090] worker 6: minfreq = 8.338909, nfreqs = 21056
# [I 200819 20:56:12 abls:1092] running...

# %%
cp = checkplot.checkplot_png(bls, dates, fluxes, errs)
# Out:
# [I 200819 20:56:28 nonphysical:216] spline fit done. nknots = 13,  chisq = 850.97735, reduced chisq = 0.62251
# [I 200819 20:56:28 png:696] plotting phased LC with period 0.734382, epoch 1949.28364
# [I 200819 20:56:28 nonphysical:216] spline fit done. nknots = 13,  chisq = 876.32254, reduced chisq = 0.64106
# [I 200819 20:56:28 png:696] plotting phased LC with period 0.367191, epoch 1945.05430
# [I 200819 20:56:28 nonphysical:216] spline fit done. nknots = 13,  chisq = 854.41110, reduced chisq = 0.62503
# [I 200819 20:56:28 png:696] plotting phased LC with period 1.468764, epoch 1946.34149
# [I 200819 20:56:28 nonphysical:216] spline fit done. nknots = 13,  chisq = 874.39847, reduced chisq = 0.63965
# [I 200819 20:56:28 png:696] plotting phased LC with period 5.891546, epoch 1946.32106
# [I 200819 20:56:28 nonphysical:216] spline fit done. nknots = 13,  chisq = 874.42113, reduced chisq = 0.63966
# [I 200819 20:56:28 png:696] plotting phased LC with period 11.796649, epoch 1940.47762
# [I 200819 20:56:28 nonphysical:216] spline fit done. nknots = 13,  chisq = 877.02758, reduced chisq = 0.64157
# [I 200819 20:56:28 png:696] plotting phased LC with period 10.309508, epoch 1940.47762
# [I 200819 20:56:28 nonphysical:216] spline fit done. nknots = 13,  chisq = 868.85746, reduced chisq = 0.63559
# [I 200819 20:56:28 png:696] plotting phased LC with period 0.174741, epoch 1965.46554
# [I 200819 20:56:29 png:1233] checkplot done -> checkplot.png

# %%
Image('0001290-checkplot-bls.png')

# %%
spdm = periodbase.stellingwerf_pdm(dates,fluxes,errs)
# Out:
# [I 200819 20:57:31 spdm:337] using autofreq with 1580 frequency points, start P = 0.100, end P = 31.690
# [I 200819 20:57:31 spdm:349] using 6 workers...

# %%
cp = checkplot.checkplot_png(spdm, dates, fluxes, errs)
# Out:
# [I 200819 20:57:35 nonphysical:216] spline fit done. nknots = 13,  chisq = 849.03442, reduced chisq = 0.62109
# [I 200819 20:57:35 png:696] plotting phased LC with period 0.736966, epoch 1972.16718
# [I 200819 20:57:35 nonphysical:216] spline fit done. nknots = 13,  chisq = 877.38666, reduced chisq = 0.64183
# [I 200819 20:57:35 png:696] plotting phased LC with period 0.368483, epoch 1940.47762
# [I 200819 20:57:35 nonphysical:216] spline fit done. nknots = 13,  chisq = 847.57091, reduced chisq = 0.62002
# [I 200819 20:57:35 png:696] plotting phased LC with period 1.473933, epoch 1962.58466
# [I 200819 20:57:35 nonphysical:216] spline fit done. nknots = 13,  chisq = 851.06284, reduced chisq = 0.62258
# [I 200819 20:57:35 png:696] plotting phased LC with period 1.467109, epoch 1950.75472
# [I 200819 20:57:35 nonphysical:216] spline fit done. nknots = 13,  chisq = 859.71323, reduced chisq = 0.62891
# [I 200819 20:57:35 png:696] plotting phased LC with period 2.200664, epoch 1960.29631
# [I 200819 20:57:35 nonphysical:216] spline fit done. nknots = 13,  chisq = 859.77625, reduced chisq = 0.62895
# [I 200819 20:57:35 png:696] plotting phased LC with period 4.401327, epoch 1940.47762
# [I 200819 20:57:35 nonphysical:216] spline fit done. nknots = 13,  chisq = 864.20488, reduced chisq = 0.63219
# [I 200819 20:57:35 png:696] plotting phased LC with period 3.047073, epoch 1940.47762
# [I 200819 20:57:36 png:1233] checkplot done -> checkplot.png

# %%
Image('0001290-checkplot-spdm.png')

# %%
print('PDM algorithm:',(spdm['nbestperiods']),'(days)')
# Out:
# PDM algorithm: [0.7369664453488356, 1.4671091273148114, 2.2006636909722173, 4.4013273819444345, 3.0470728028846086] (days)

# %%
df=pd.read_table('/Users/kornk/OneDrive/Documents/GitHub/UW-Lightcurves/K2Campaign0SuperStampLCs/photref.cat',sep='\s+')
HATID='HAT-264-0001290'
itemindex = np.where(df['HATID']==HATID)
print(itemindex[0])
RA=float(df.RA[itemindex[0]])
DEC=float(df.DEC[itemindex[0]])
print(RA,DEC)
# Out:
# [8202]
# 92.3601025 24.380371899999997

# %%
fileout='0001290.pkl'
cpf = checkplot.checkplot_pickle([glsp,spdm,bls],dates,fluxes,errs,outfile=fileout,objectinfo={'ra': RA,'decl': DEC})
# Out:
# [W 200819 20:58:53 pkl:604] adding a randomly generated objectid since none was provided in objectinfo dict
# [I 200819 20:58:53 pkl_utils:415] adding in object information and finder chart for 6e180 at RA: 92.360, DEC: 24.380
# [I 200819 20:58:55 skyview:209] submitting stamp request for 92.3601, 24.3804, DSS2 Red, Linear, 300
# [I 200819 20:58:59 skyview:233] getting https://skyview.gsfc.nasa.gov/tempspace/fits/skv26743832924903.fits
# [I 200819 20:59:00 plotbase:964] fetched stamp successfully for (92.360, 24.380)
# [W 200819 20:59:04 pkl_utils:765] pmRA not found in provided objectinfo dict, using value from GAIA
# [W 200819 20:59:04 pkl_utils:783] pmDEC not found in provided objectinfo dict, using value from GAIA
# [I 200819 20:59:05 mast:245] query successful. nmatches: 2
# [W 200819 20:59:09 pkl:661] times is an astropy.table.Column object, changing to numpy array because of potential unpickling issues
# [W 200819 20:59:09 pkl:666] mags is an astropy.table.Column object, changing to numpy array because of potential unpickling issues
# [W 200819 20:59:09 pkl:671] errs is an astropy.table.Column object, changing to numpy array because of potential unpickling issues
# [I 200819 20:59:09 pkl:677] sigclip = 4.0: before = 1386 observations, after = 1381 observations
# [I 200819 20:59:09 nonphysical:216] spline fit done. nknots = 13,  chisq = 849.03442, reduced chisq = 0.62109
# [I 200819 20:59:09 pkl_utils:1710] plotting gls phased LC with period 0: 0.736966, epoch: 1972.16718
# [I 200819 20:59:09 nonphysical:216] spline fit done. nknots = 13,  chisq = 864.80040, reduced chisq = 0.63263
# [I 200819 20:59:09 pkl_utils:1710] plotting gls phased LC with period 1: 0.101961, epoch: 1955.00450
# [I 200819 20:59:09 nonphysical:216] spline fit done. nknots = 13,  chisq = 865.59033, reduced chisq = 0.63320
# [I 200819 20:59:09 pkl_utils:1710] plotting gls phased LC with period 2: 0.174694, epoch: 1940.47762
# [I 200819 20:59:10 nonphysical:216] spline fit done. nknots = 13,  chisq = 849.03442, reduced chisq = 0.62109
# [I 200819 20:59:10 pkl_utils:1710] plotting pdm phased LC with period 0: 0.736966, epoch: 1972.16718
# [I 200819 20:59:10 nonphysical:216] spline fit done. nknots = 13,  chisq = 851.06284, reduced chisq = 0.62258
# [I 200819 20:59:10 pkl_utils:1710] plotting pdm phased LC with period 1: 1.467109, epoch: 1950.75472
# [I 200819 20:59:10 nonphysical:216] spline fit done. nknots = 13,  chisq = 859.71323, reduced chisq = 0.62891
# [I 200819 20:59:10 pkl_utils:1710] plotting pdm phased LC with period 2: 2.200664, epoch: 1960.29631
# [I 200819 20:59:10 nonphysical:216] spline fit done. nknots = 13,  chisq = 850.97735, reduced chisq = 0.62251
# [I 200819 20:59:10 pkl_utils:1710] plotting bls phased LC with period 0: 0.734382, epoch: 1949.28364
# [I 200819 20:59:10 nonphysical:216] spline fit done. nknots = 13,  chisq = 874.39847, reduced chisq = 0.63965
# [I 200819 20:59:10 pkl_utils:1710] plotting bls phased LC with period 1: 5.891546, epoch: 1946.32106
# [I 200819 20:59:10 nonphysical:216] spline fit done. nknots = 13,  chisq = 874.42113, reduced chisq = 0.63966
# [I 200819 20:59:10 pkl_utils:1710] plotting bls phased LC with period 2: 11.796649, epoch: 1940.47762
# [I 200819 20:59:11 pkl:873] checkplot dict complete for 6e180
# [I 200819 20:59:11 pkl:875] checkplot dict contents: ['0-gls', '1-pdm', '2-bls', 'comments', 'externalplots', 'finderchart', 'magseries', 'neighbors', 'normmingap', 'normto', 'objectid', 'objectinfo', 'sigclip', 'signals', 'varinfo']
# [I 200819 20:59:11 pkl:1489] checkplot done -> C:\Users\kornk\OneDrive\Documents\GitHub\UW-Lightcurves\K2Campaign0SuperStampLCs\HAT-264-0001290\0001290.pkl

# %%
cpfpng = checkplot.checkplot_pickle_to_png(fileout, 'checkplot-pickle.png')
Image('0001290-checkplot-pickle.png')
# Out:
# [I 200819 20:59:12 pkl_png:1076] checkplot pickle -> checkplot PNG: checkplot-pickle.png OK
