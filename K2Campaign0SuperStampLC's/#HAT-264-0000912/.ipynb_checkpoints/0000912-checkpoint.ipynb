# %%
from astropy.table import Table
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
outpath='HAT-264-0000912.rlc.tfalc'
data=Table.read(outpath,format='ascii')
t=data['col2']
mag=data['col8']

# %%
plt.figure(figsize=(20,8))
plt.plot(t,mag,'yo',markersize=10,label='HAT-264-0000912')
plt.ylabel('Relative Magnitude')
plt.xlabel('time (BJD-2454833)')
# Out:
# Text(0.5, 0, 'time (BJD-2454833)')

# %%
import astrobase
from astrobase import periodbase, checkplot
periodbase.use_astropy_bls()
# Out:
# [I 200817 14:30:22 __init__:84] An Astropy implementation of BLS is available because Astropy >= 3.1.
# [I 200817 14:30:22 __init__:86] If you want to use it as the default periodbase BLS runner, call the periodbase.use_astropy_bls() function.

# %%
dates=data['col2']
fluxes=data['col8']
errs=fluxes*0.01

# %%
glsp = periodbase.pgen_lsp(dates,fluxes,errs)
# Out:
# [I 200817 14:30:27 zgls:597] using autofreq with 1580 frequency points, start P = 0.100, end P = 31.690
# [I 200817 14:30:27 zgls:607] using 6 workers...

# %%
cp = checkplot.checkplot_png(glsp, dates, fluxes, errs)
# Out:
# [I 200817 14:30:30 nonphysical:216] spline fit done. nknots = 13,  chisq = 13581214.25423, reduced chisq = 9942.32376
# [I 200817 14:30:30 png:696] plotting phased LC with period 0.381802, epoch 1969.87882
# [I 200817 14:30:30 nonphysical:216] spline fit done. nknots = 13,  chisq = 13616715.81757, reduced chisq = 9968.31319
# [I 200817 14:30:30 png:696] plotting phased LC with period 0.190901, epoch 1940.47763
# [I 200817 14:30:30 nonphysical:216] spline fit done. nknots = 13,  chisq = 13607620.69254, reduced chisq = 9961.65497
# [I 200817 14:30:30 png:696] plotting phased LC with period 0.763604, epoch 1940.47763
# [I 200817 14:30:30 nonphysical:216] spline fit done. nknots = 13,  chisq = 13557567.61265, reduced chisq = 9925.01289
# [I 200817 14:30:30 png:696] plotting phased LC with period 0.180876, epoch 1963.81058
# [I 200817 14:30:30 nonphysical:216] spline fit done. nknots = 13,  chisq = 13515126.53322, reduced chisq = 9893.94329
# [I 200817 14:30:30 png:696] plotting phased LC with period 0.329413, epoch 1948.52769
# [I 200817 14:30:30 nonphysical:216] spline fit done. nknots = 13,  chisq = 13616490.68753, reduced chisq = 9975.45105
# [I 200817 14:30:30 png:696] plotting phased LC with period 0.107059, epoch 1966.81405
# [I 200817 14:30:30 nonphysical:216] spline fit done. nknots = 13,  chisq = 13588918.47849, reduced chisq = 9947.96375
# [I 200817 14:30:30 png:696] plotting phased LC with period 0.280439, epoch 1955.63790
# [I 200817 14:30:32 png:1233] checkplot done -> checkplot.png

# %%
from IPython.display import Image
Image('0000912-checkplot-glsp.png')

# %%
glsp
# Out:
# {'bestperiod': 0.3818018738554218,
#  'bestlspval': 0.005361656002795907,
#  'nbestpeaks': 5,
#  'nbestlspvals': [0.005361656002795907,
#   0.004508517534786217,
#   0.004431339686159149,
#   0.0042779025811292195,
#   0.004265727228695191],
#  'nbestperiods': [0.3818018738554218,
#   0.18087645850456624,
#   0.3294132591476092,
#   0.107059309222973,
#   0.2804385445132744],
#  'lspvals': array([1.98983328e-03, 2.43327724e-03, 1.88995795e-03, ...,
#         1.49649413e-04, 2.39583329e-05, 5.32482977e-06]),
#  'omegas': array([ 0.19827307,  0.23792768,  0.27758229, ..., 62.7335978 ,
#         62.77325242, 62.81290703]),
#  'periods': array([31.68955553, 26.40796294, 22.63539681, ...,  0.10015662,
#          0.10009335,  0.10003016]),
#  'method': 'gls',
#  'kwargs': {'startp': None,
#   'endp': None,
#   'stepsize': 0.0001,
#   'autofreq': True,
#   'periodepsilon': 0.1,
#   'nbestpeaks': 5,
#   'sigclip': 10.0}}

# %%
print('LS algorithm:',(glsp['nbestperiods']),'(days)')
# Out:
# LS algorithm: [0.3818018738554218, 0.18087645850456624, 0.3294132591476092, 0.107059309222973, 0.2804385445132744] (days)

# %%
bls=periodbase.bls_parallel_pfind(dates,fluxes,errs)
# Out:
# [I 200817 14:31:16 abls:919] min P: 0.1, max P: 100.0, nfreq: 126632, minfreq: 0.01, maxfreq: 10.0
# [I 200817 14:31:16 abls:922] autofreq = True: using AUTOMATIC values for freq stepsize: 7.889034598902118e-05, ndurations: 100, min transit duration: 0.01, max transit duration: 0.4
# [W 200817 14:31:16 abls:964] the requested max P = 100.000 is larger than the time base of the observations = 31.690,  will make minfreq = 2 x 1/timebase
# [W 200817 14:31:16 abls:969] new minfreq: 0.06311227679121695, maxfreq: 10.0
# [I 200817 14:31:16 abls:980] using 6 workers...
# [I 200817 14:31:16 abls:1090] worker 1: minfreq = 0.063112, nfreqs = 21105
# [I 200817 14:31:16 abls:1090] worker 2: minfreq = 1.728093, nfreqs = 21105
# [I 200817 14:31:16 abls:1090] worker 3: minfreq = 3.393074, nfreqs = 21105
# [I 200817 14:31:16 abls:1090] worker 4: minfreq = 5.058055, nfreqs = 21105
# [I 200817 14:31:16 abls:1090] worker 5: minfreq = 6.723035, nfreqs = 21105
# [I 200817 14:31:16 abls:1090] worker 6: minfreq = 8.388016, nfreqs = 21107
# [I 200817 14:31:16 abls:1092] running...
# [E 200817 14:31:28 abls:1125] no finite periodogram values for this mag series, skipping...

# %%
cp = checkplot.checkplot_png(bls, dates, fluxes, errs)
# Out:
# [W 200817 14:31:28 png:1142] no best period found for this object, skipping...

# %%
spdm = periodbase.stellingwerf_pdm(dates,fluxes,errs)
# Out:
# [I 200817 14:31:39 spdm:337] using autofreq with 1580 frequency points, start P = 0.100, end P = 31.690
# [I 200817 14:31:39 spdm:349] using 6 workers...

# %%
cp = checkplot.checkplot_png(spdm, dates, fluxes, errs)
# Out:
# [I 200817 14:31:47 nonphysical:216] spline fit done. nknots = 13,  chisq = 13486434.66658, reduced chisq = 9872.93899
# [I 200817 14:31:47 png:696] plotting phased LC with period 22.635397, epoch 1960.29632
# [I 200817 14:31:47 nonphysical:216] spline fit done. nknots = 13,  chisq = 13517913.83782, reduced chisq = 9895.98378
# [I 200817 14:31:47 png:696] plotting phased LC with period 11.317698, epoch 1962.56424
# [I 200817 14:31:47 nonphysical:216] spline fit done. nknots = 13,  chisq = 13538936.30377, reduced chisq = 9911.37358
# [I 200817 14:31:47 png:696] plotting phased LC with period 45.270794, epoch 1970.24660
# [I 200817 14:31:47 nonphysical:216] spline fit done. nknots = 13,  chisq = 13548370.38095, reduced chisq = 9918.27993
# [I 200817 14:31:47 png:696] plotting phased LC with period 31.689556, epoch 1970.28746
# [I 200817 14:31:47 nonphysical:216] spline fit done. nknots = 13,  chisq = 13559376.88855, reduced chisq = 9926.33740
# [I 200817 14:31:47 png:696] plotting phased LC with period 19.805972, epoch 1940.66152
# [I 200817 14:31:47 nonphysical:216] spline fit done. nknots = 13,  chisq = 13612940.20645, reduced chisq = 9965.54920
# [I 200817 14:31:47 png:696] plotting phased LC with period 10.563185, epoch 1951.04077
# [I 200817 14:31:48 nonphysical:216] spline fit done. nknots = 13,  chisq = 13609453.16051, reduced chisq = 9962.99646
# [I 200817 14:31:48 png:696] plotting phased LC with period 26.407963, epoch 1940.47763
# [I 200817 14:31:48 png:1233] checkplot done -> checkplot.png

# %%
Image('0000912-checkplot-spdm.png')

# %%
print('PDM algorithm:',(spdm['nbestperiods']),'(days)')
# Out:
# PDM algorithm: [22.63539680714286, 31.689555530000003, 19.805972206250004, 10.563185176666668, 26.40796294166667] (days)
