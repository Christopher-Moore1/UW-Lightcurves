# %%
from astropy.table import Table
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
outpath='HAT-264-0000887.rlc.tfalc'
data=Table.read(outpath,format='ascii')
t=data['col2']
mag=data['col8']

# %%
plt.figure(figsize=(20,8))
plt.plot(t,mag,'yo',markersize=10,label='HAT-264-0000887')
plt.ylabel('Relative Magnitude')
plt.xlabel('time (BJD-2454833)')
# Out:
# Text(0.5, 0, 'time (BJD-2454833)')

# %%
import astrobase
from astrobase import periodbase, checkplot
periodbase.use_astropy_bls()
# Out:
# [I 200817 14:23:57 __init__:84] An Astropy implementation of BLS is available because Astropy >= 3.1.
# [I 200817 14:23:57 __init__:86] If you want to use it as the default periodbase BLS runner, call the periodbase.use_astropy_bls() function.

# %%
dates=data['col2']
fluxes=data['col8']
errs=fluxes*0.01

# %%
glsp = periodbase.pgen_lsp(dates,fluxes,errs)
# Out:
# [I 200817 14:24:00 zgls:597] using autofreq with 1579 frequency points, start P = 0.100, end P = 31.669
# [I 200817 14:24:00 zgls:607] using 6 workers...

# %%
cp = checkplot.checkplot_png(glsp, dates, fluxes, errs)
# Out:
# [I 200817 14:24:03 nonphysical:216] spline fit done. nknots = 13,  chisq = 13046968.51793, reduced chisq = 9736.54367
# [I 200817 14:24:03 png:696] plotting phased LC with period 0.140129, epoch 1950.44818
# [I 200817 14:24:03 nonphysical:216] spline fit done. nknots = 13,  chisq = 13243169.88795, reduced chisq = 9882.96260
# [I 200817 14:24:03 png:696] plotting phased LC with period 0.070064, epoch 1940.49799
# [I 200817 14:24:03 nonphysical:216] spline fit done. nknots = 13,  chisq = 13106778.34204, reduced chisq = 9781.17787
# [I 200817 14:24:03 png:696] plotting phased LC with period 0.280258, epoch 1957.31322
# [I 200817 14:24:03 nonphysical:216] spline fit done. nknots = 13,  chisq = 13157569.09315, reduced chisq = 9819.08141
# [I 200817 14:24:03 png:696] plotting phased LC with period 0.363178, epoch 1960.11236
# [I 200817 14:24:03 nonphysical:216] spline fit done. nknots = 13,  chisq = 13087522.94460, reduced chisq = 9766.80817
# [I 200817 14:24:03 png:696] plotting phased LC with period 0.182847, epoch 1969.26580
# [I 200817 14:24:03 nonphysical:216] spline fit done. nknots = 13,  chisq = 13195389.70055, reduced chisq = 9847.30575
# [I 200817 14:24:03 png:696] plotting phased LC with period 1.885068, epoch 1940.49799
# [I 200817 14:24:03 nonphysical:216] spline fit done. nknots = 13,  chisq = 13269672.23035, reduced chisq = 9902.74047
# [I 200817 14:24:03 png:696] plotting phased LC with period 0.156468, epoch 1940.92705
# [I 200817 14:24:04 png:1233] checkplot done -> checkplot.png

# %%
from IPython.display import Image
Image('0000887-checkplot-glsp.png')

# %%
glsp
# Out:
# {'bestperiod': 0.14012891349557519,
#  'bestlspval': 0.013175705023007868,
#  'nbestpeaks': 5,
#  'nbestlspvals': [0.013175705023007868,
#   0.010222079229921039,
#   0.009630050193820513,
#   0.008241798491136551,
#   0.006349046719580766],
#  'nbestperiods': [0.14012891349557519,
#   0.3631781473623853,
#   0.18284719659353346,
#   1.8850675267857142,
#   0.15646805558300392],
#  'lspvals': array([0.00025324, 0.00016144, 0.00028179, ..., 0.00100869, 0.00071343,
#         0.00042808]),
#  'omegas': array([ 0.19840092,  0.2380811 ,  0.27776128, ..., 62.73436987,
#         62.77405006, 62.81373024]),
#  'periods': array([31.66913445, 26.39094537, 22.62081032, ...,  0.10015539,
#          0.10009208,  0.10002885]),
#  'method': 'gls',
#  'kwargs': {'startp': None,
#   'endp': None,
#   'stepsize': 0.0001,
#   'autofreq': True,
#   'periodepsilon': 0.1,
#   'nbestpeaks': 5,
#   'sigclip': 10.0}}

# %%
print('LS algorithm:',(glsp['nbestperiods']),'(days)')
# Out:
# LS algorithm: [0.14012891349557519, 0.3631781473623853, 0.18284719659353346, 1.8850675267857142, 0.15646805558300392] (days)

# %%
bls=periodbase.bls_parallel_pfind(dates,fluxes,errs)
# Out:
# [I 200817 14:24:45 abls:919] min P: 0.1, max P: 100.0, nfreq: 126632, minfreq: 0.01, maxfreq: 10.0
# [I 200817 14:24:45 abls:922] autofreq = True: using AUTOMATIC values for freq stepsize: 7.889031960059845e-05, ndurations: 100, min transit duration: 0.01, max transit duration: 0.4
# [W 200817 14:24:45 abls:964] the requested max P = 100.000 is larger than the time base of the observations = 31.690,  will make minfreq = 2 x 1/timebase
# [W 200817 14:24:45 abls:969] new minfreq: 0.06311225568047876, maxfreq: 10.0
# [I 200817 14:24:45 abls:980] using 6 workers...
# [I 200817 14:24:45 abls:1090] worker 1: minfreq = 0.063112, nfreqs = 21105
# [I 200817 14:24:45 abls:1090] worker 2: minfreq = 1.728092, nfreqs = 21105
# [I 200817 14:24:45 abls:1090] worker 3: minfreq = 3.393073, nfreqs = 21105
# [I 200817 14:24:45 abls:1090] worker 4: minfreq = 5.058053, nfreqs = 21105
# [I 200817 14:24:45 abls:1090] worker 5: minfreq = 6.723033, nfreqs = 21105
# [I 200817 14:24:45 abls:1090] worker 6: minfreq = 8.388013, nfreqs = 21107
# [I 200817 14:24:45 abls:1092] running...
# [E 200817 14:24:57 abls:1125] no finite periodogram values for this mag series, skipping...

# %%
cp = checkplot.checkplot_png(bls, dates, fluxes, errs)
# Out:
# [W 200817 14:24:57 png:1142] no best period found for this object, skipping...

# %%
spdm = periodbase.stellingwerf_pdm(dates,fluxes,errs)
# Out:
# [I 200817 14:25:02 spdm:337] using autofreq with 1580 frequency points, start P = 0.100, end P = 31.690
# [I 200817 14:25:02 spdm:349] using 6 workers...

# %%
cp = checkplot.checkplot_png(spdm, dates, fluxes, errs)
# Out:
# [I 200817 14:25:05 nonphysical:216] spline fit done. nknots = 13,  chisq = 13302295.66521, reduced chisq = 9927.08632
# [I 200817 14:25:05 png:696] plotting phased LC with period 0.776705, epoch 1940.49799
# [I 200817 14:25:05 nonphysical:216] spline fit done. nknots = 13,  chisq = 13312428.18989, reduced chisq = 9934.64790
# [I 200817 14:25:05 png:696] plotting phased LC with period 0.388353, epoch 1940.49799
# [I 200817 14:25:06 nonphysical:216] spline fit done. nknots = 13,  chisq = 13303576.86922, reduced chisq = 9928.04244
# [I 200817 14:25:06 png:696] plotting phased LC with period 1.553410, epoch 1940.49799
# [I 200817 14:25:06 nonphysical:216] spline fit done. nknots = 13,  chisq = 13206982.69402, reduced chisq = 9855.95723
# [I 200817 14:25:06 png:696] plotting phased LC with period 0.452708, epoch 1940.49799
# [I 200817 14:25:06 nonphysical:216] spline fit done. nknots = 13,  chisq = 13236032.85416, reduced chisq = 9877.63646
# [I 200817 14:25:06 png:696] plotting phased LC with period 0.124664, epoch 1940.49799
# [I 200817 14:25:06 nonphysical:216] spline fit done. nknots = 13,  chisq = 13229559.27227, reduced chisq = 9872.80543
# [I 200817 14:25:06 png:696] plotting phased LC with period 0.972073, epoch 1940.49799
# [I 200817 14:25:06 nonphysical:216] spline fit done. nknots = 13,  chisq = 13326616.56166, reduced chisq = 9945.23624
# [I 200817 14:25:06 png:696] plotting phased LC with period 0.277979, epoch 1940.49799
# [I 200817 14:25:07 png:1233] checkplot done -> checkplot.png

# %%
Image('0000887-checkplot-spdm.png')

# %%
print('PDM algorithm:',(spdm['nbestperiods']),'(days)')
# Out:
# PDM algorithm: [0.7767050522058824, 0.45270808757142855, 0.12466391081825334, 0.9720725806748466, 0.27797865026315793] (days)
