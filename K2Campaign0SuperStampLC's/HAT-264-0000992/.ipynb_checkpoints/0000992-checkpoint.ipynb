# %%
from astropy.table import Table
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
outpath='HAT-264-0000992.rlc.tfalc'
data=Table.read(outpath,format='ascii')
t=data['col2']
mag=data['col8']

# %%
plt.figure(figsize=(20,8))
plt.plot(t,mag,'yo',markersize=10,label='HAT-264-0000992')
plt.ylabel('Relative Magnitude')
plt.xlabel('time (BJD-2454833)')
# Out:
# Text(0.5, 0, 'time (BJD-2454833)')

# %%
import astrobase
from astrobase import periodbase, checkplot
periodbase.use_astropy_bls()
# Out:
# [I 200817 15:02:18 __init__:84] An Astropy implementation of BLS is available because Astropy >= 3.1.
# [I 200817 15:02:18 __init__:86] If you want to use it as the default periodbase BLS runner, call the periodbase.use_astropy_bls() function.

# %%
dates=data['col2']
fluxes=data['col8']
errs=fluxes*0.01

# %%
glsp = periodbase.pgen_lsp(dates,fluxes,errs)
# Out:
# [I 200817 15:02:21 zgls:597] using autofreq with 1579 frequency points, start P = 0.100, end P = 31.669
# [I 200817 15:02:21 zgls:607] using 6 workers...

# %%
cp = checkplot.checkplot_png(glsp, dates, fluxes, errs)
# Out:
# [I 200817 15:02:24 nonphysical:216] spline fit done. nknots = 13,  chisq = 13098325.20166, reduced chisq = 9892.99487
# [I 200817 15:02:24 png:696] plotting phased LC with period 1.123019, epoch 1940.49805
# [I 200817 15:02:24 nonphysical:216] spline fit done. nknots = 13,  chisq = 13170405.93602, reduced chisq = 9947.43651
# [I 200817 15:02:24 png:696] plotting phased LC with period 0.561509, epoch 1940.49805
# [I 200817 15:02:24 nonphysical:216] spline fit done. nknots = 13,  chisq = 13028208.99816, reduced chisq = 9840.03701
# [I 200817 15:02:24 png:696] plotting phased LC with period 2.246037, epoch 1971.94243
# [I 200817 15:02:24 nonphysical:216] spline fit done. nknots = 13,  chisq = 13110938.42875, reduced chisq = 9902.52147
# [I 200817 15:02:24 png:696] plotting phased LC with period 0.129685, epoch 1969.36801
# [I 200817 15:02:24 nonphysical:216] spline fit done. nknots = 13,  chisq = 13092601.95985, reduced chisq = 9896.14661
# [I 200817 15:02:24 png:696] plotting phased LC with period 0.355833, epoch 1940.49805
# [I 200817 15:02:24 nonphysical:216] spline fit done. nknots = 13,  chisq = 13100459.31477, reduced chisq = 9894.60673
# [I 200817 15:02:24 png:696] plotting phased LC with period 0.174582, epoch 1960.05113
# [I 200817 15:02:25 nonphysical:216] spline fit done. nknots = 13,  chisq = 13169104.62218, reduced chisq = 9946.45364
# [I 200817 15:02:25 png:696] plotting phased LC with period 0.750453, epoch 1940.49805
# [I 200817 15:02:26 png:1233] checkplot done -> checkplot.png

# %%
from IPython.display import Image
Image('0000992-checkplot-glsp.png')

# %%
glsp
# Out:
# {'bestperiod': 1.1230186333333343,
#  'bestlspval': 0.0140916014736988,
#  'nbestpeaks': 5,
#  'nbestlspvals': [0.0140916014736988,
#   0.008608770891234909,
#   0.007487833689339153,
#   0.007278993136201624,
#   0.006263848173317548],
#  'nbestperiods': [1.1230186333333343,
#   0.12968519844389856,
#   0.355832870337079,
#   0.17458172800441032,
#   0.7504532099526073],
#  'lspvals': array([4.27842412e-04, 5.67974489e-04, 7.03471194e-04, ...,
#         3.33146464e-05, 1.10508287e-04, 4.41764342e-04]),
#  'omegas': array([ 0.19840097,  0.23808117,  0.27776136, ..., 62.73438768,
#         62.77406788, 62.81374807]),
#  'periods': array([31.66912546, 26.39093788, 22.6208039 , ...,  0.10015536,
#          0.10009205,  0.10002882]),
#  'method': 'gls',
#  'kwargs': {'startp': None,
#   'endp': None,
#   'stepsize': 0.0001,
#   'autofreq': True,
#   'periodepsilon': 0.1,
#   'nbestpeaks': 5,
#   'sigclip': 10.0}}

# %%
print('LS algorithm:',(glsp['nbestperiods']),'(days)')
# Out:
# LS algorithm: [1.1230186333333343, 0.12968519844389856, 0.355832870337079, 0.17458172800441032, 0.7504532099526073] (days)

# %%
bls=periodbase.bls_parallel_pfind(dates,fluxes,errs)
# Out:
# [I 200817 15:03:25 abls:919] min P: 0.1, max P: 100.0, nfreq: 126632, minfreq: 0.01, maxfreq: 10.0
# [I 200817 15:03:25 abls:922] autofreq = True: using AUTOMATIC values for freq stepsize: 7.889034195607261e-05, ndurations: 100, min transit duration: 0.01, max transit duration: 0.4
# [W 200817 15:03:25 abls:964] the requested max P = 100.000 is larger than the time base of the observations = 31.690,  will make minfreq = 2 x 1/timebase
# [W 200817 15:03:25 abls:969] new minfreq: 0.06311227356485809, maxfreq: 10.0
# [I 200817 15:03:25 abls:980] using 6 workers...
# [I 200817 15:03:25 abls:1090] worker 1: minfreq = 0.063112, nfreqs = 21105
# [I 200817 15:03:25 abls:1090] worker 2: minfreq = 1.728093, nfreqs = 21105
# [I 200817 15:03:25 abls:1090] worker 3: minfreq = 3.393074, nfreqs = 21105
# [I 200817 15:03:25 abls:1090] worker 4: minfreq = 5.058054, nfreqs = 21105
# [I 200817 15:03:25 abls:1090] worker 5: minfreq = 6.723035, nfreqs = 21105
# [I 200817 15:03:25 abls:1090] worker 6: minfreq = 8.388016, nfreqs = 21107
# [I 200817 15:03:25 abls:1092] running...
# [E 200817 15:03:37 abls:1125] no finite periodogram values for this mag series, skipping...

# %%
cp = checkplot.checkplot_png(bls, dates, fluxes, errs)
# Out:
# [W 200817 15:03:37 png:1142] no best period found for this object, skipping...

# %%
spdm = periodbase.stellingwerf_pdm(dates,fluxes,errs)
# Out:
# [I 200817 15:03:41 spdm:337] using autofreq with 1580 frequency points, start P = 0.100, end P = 31.690
# [I 200817 15:03:41 spdm:349] using 6 workers...

# %%
cp = checkplot.checkplot_png(spdm, dates, fluxes, errs)
# Out:
# [I 200817 15:03:45 nonphysical:216] spline fit done. nknots = 13,  chisq = 13163476.33101, reduced chisq = 9942.20267
# [I 200817 15:03:45 png:696] plotting phased LC with period 1.480820, epoch 1940.49805
# [I 200817 15:03:45 nonphysical:216] spline fit done. nknots = 13,  chisq = 13153895.71009, reduced chisq = 9934.96655
# [I 200817 15:03:45 png:696] plotting phased LC with period 0.740410, epoch 1940.49805
# [I 200817 15:03:45 nonphysical:216] spline fit done. nknots = 13,  chisq = 13155997.17403, reduced chisq = 9936.55376
# [I 200817 15:03:45 png:696] plotting phased LC with period 2.961641, epoch 1940.49805
# [I 200817 15:03:45 nonphysical:216] spline fit done. nknots = 13,  chisq = 13100485.60134, reduced chisq = 9894.62659
# [I 200817 15:03:45 png:696] plotting phased LC with period 0.743886, epoch 1940.49805
# [I 200817 15:03:45 nonphysical:216] spline fit done. nknots = 13,  chisq = 13074836.32618, reduced chisq = 9875.25402
# [I 200817 15:03:45 png:696] plotting phased LC with period 2.231659, epoch 1964.07618
# [I 200817 15:03:45 nonphysical:216] spline fit done. nknots = 13,  chisq = 13177385.79345, reduced chisq = 9952.70830
# [I 200817 15:03:45 png:696] plotting phased LC with period 0.119313, epoch 1967.57001
# [I 200817 15:03:45 nonphysical:216] spline fit done. nknots = 13,  chisq = 13130168.52704, reduced chisq = 9917.04572
# [I 200817 15:03:45 png:696] plotting phased LC with period 2.989581, epoch 1970.38961
# [I 200817 15:03:46 png:1233] checkplot done -> checkplot.png

# %%
Image('0000992-checkplot-spdm.png')

# %%
print('PDM algorithm:',(spdm['nbestperiods']),'(days)')
# Out:
# PDM algorithm: [1.4808204275700898, 0.7438863180751156, 2.231658954225347, 0.1193130916792166, 2.9895808632075407] (days)
