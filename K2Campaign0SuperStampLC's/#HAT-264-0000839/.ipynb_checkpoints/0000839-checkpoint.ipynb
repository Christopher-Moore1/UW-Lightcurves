# %%
from astropy.table import Table
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
outpath='HAT-264-0000839.rlc.tfalc'
data=Table.read(outpath,format='ascii')
t=data['col2']
mag=data['col8']

# %%
plt.figure(figsize=(20,8))
plt.plot(t,mag,'yo',markersize=10,label='HAT-264-0000839')
plt.ylabel('Relative Magnitude')
plt.xlabel('time (BJD-2454833)')
# Out:
# Text(0.5, 0, 'time (BJD-2454833)')

# %%
import astrobase
from astrobase import periodbase, checkplot
periodbase.use_astropy_bls()
# Out:
# [I 200817 14:14:54 __init__:84] An Astropy implementation of BLS is available because Astropy >= 3.1.
# [I 200817 14:14:54 __init__:86] If you want to use it as the default periodbase BLS runner, call the periodbase.use_astropy_bls() function.

# %%
dates=data['col2']
fluxes=data['col8']
errs=fluxes*0.01

# %%
glsp = periodbase.pgen_lsp(dates,fluxes,errs)
# Out:
# [I 200817 14:14:55 zgls:597] using autofreq with 1580 frequency points, start P = 0.100, end P = 31.690
# [I 200817 14:14:55 zgls:607] using 6 workers...

# %%
cp = checkplot.checkplot_png(glsp, dates, fluxes, errs)
# Out:
# [I 200817 14:14:58 nonphysical:216] spline fit done. nknots = 13,  chisq = 13453956.73641, reduced chisq = 9827.57979
# [I 200817 14:14:58 png:696] plotting phased LC with period 0.554013, epoch 1969.28626
# [I 200817 14:14:58 nonphysical:216] spline fit done. nknots = 13,  chisq = 13444565.61716, reduced chisq = 9820.71995
# [I 200817 14:14:58 png:696] plotting phased LC with period 0.277007, epoch 1952.94087
# [I 200817 14:14:58 nonphysical:216] spline fit done. nknots = 13,  chisq = 13411752.70201, reduced chisq = 9796.75143
# [I 200817 14:14:58 png:696] plotting phased LC with period 1.108027, epoch 1969.28626
# [I 200817 14:14:59 nonphysical:216] spline fit done. nknots = 13,  chisq = 13489704.02813, reduced chisq = 9853.69177
# [I 200817 14:14:59 png:696] plotting phased LC with period 0.129875, epoch 1972.16715
# [I 200817 14:14:59 nonphysical:216] spline fit done. nknots = 13,  chisq = 13307596.14639, reduced chisq = 9720.66921
# [I 200817 14:14:59 png:696] plotting phased LC with period 0.160210, epoch 1960.66405
# [I 200817 14:14:59 nonphysical:216] spline fit done. nknots = 13,  chisq = 13487688.91517, reduced chisq = 9852.21981
# [I 200817 14:14:59 png:696] plotting phased LC with period 0.207664, epoch 1964.56651
# [I 200817 14:14:59 nonphysical:216] spline fit done. nknots = 13,  chisq = 13345116.48909, reduced chisq = 9748.07633
# [I 200817 14:14:59 png:696] plotting phased LC with period 2.437659, epoch 1964.85256
# [I 200817 14:15:00 png:1233] checkplot done -> checkplot.png

# %%
from IPython.display import Image
Image('0000839-checkplot-glsp.png')

# %%
glsp
# Out:
# {'bestperiod': 0.554013303846152,
#  'bestlspval': 0.012241912693613573,
#  'nbestpeaks': 5,
#  'nbestlspvals': [0.012241912693613573,
#   0.011590813002137313,
#   0.011027675792748352,
#   0.010541211284136235,
#   0.00927884995112581],
#  'nbestperiods': [0.554013303846152,
#   0.12987524991803237,
#   0.16021011617795702,
#   0.2076642266055039,
#   2.4376585369230686],
#  'lspvals': array([0.00034636, 0.00032678, 0.00156047, ..., 0.00172724, 0.00136379,
#         0.00104097]),
#  'omegas': array([ 0.19827303,  0.23792764,  0.27758224, ..., 62.73358701,
#         62.77324162, 62.81289623]),
#  'periods': array([31.68956098, 26.40796748, 22.6354007 , ...,  0.10015664,
#          0.10009337,  0.10003018]),
#  'method': 'gls',
#  'kwargs': {'startp': None,
#   'endp': None,
#   'stepsize': 0.0001,
#   'autofreq': True,
#   'periodepsilon': 0.1,
#   'nbestpeaks': 5,
#   'sigclip': 10.0}}

# %%
print('LS algorithm:',(glsp['nbestperiods']),'(days)')
# Out:
# LS algorithm: [0.554013303846152, 0.12987524991803237, 0.16021011617795702, 0.2076642266055039, 2.4376585369230686] (days)

# %%
bls=periodbase.bls_parallel_pfind(dates,fluxes,errs)
# Out:
# [I 200817 14:15:25 abls:919] min P: 0.1, max P: 100.0, nfreq: 126632, minfreq: 0.01, maxfreq: 10.0
# [I 200817 14:15:25 abls:922] autofreq = True: using AUTOMATIC values for freq stepsize: 7.88903324213868e-05, ndurations: 100, min transit duration: 0.01, max transit duration: 0.4
# [W 200817 14:15:25 abls:964] the requested max P = 100.000 is larger than the time base of the observations = 31.690,  will make minfreq = 2 x 1/timebase
# [W 200817 14:15:25 abls:969] new minfreq: 0.06311226593710945, maxfreq: 10.0
# [I 200817 14:15:25 abls:980] using 6 workers...
# [I 200817 14:15:25 abls:1090] worker 1: minfreq = 0.063112, nfreqs = 21105
# [I 200817 14:15:25 abls:1090] worker 2: minfreq = 1.728093, nfreqs = 21105
# [I 200817 14:15:25 abls:1090] worker 3: minfreq = 3.393073, nfreqs = 21105
# [I 200817 14:15:25 abls:1090] worker 4: minfreq = 5.058054, nfreqs = 21105
# [I 200817 14:15:25 abls:1090] worker 5: minfreq = 6.723034, nfreqs = 21105
# [I 200817 14:15:25 abls:1090] worker 6: minfreq = 8.388015, nfreqs = 21107
# [I 200817 14:15:25 abls:1092] running...
# [E 200817 14:15:37 abls:1125] no finite periodogram values for this mag series, skipping...

# %%
cp = checkplot.checkplot_png(bls, dates, fluxes, errs)
# Out:
# [W 200817 14:15:37 png:1142] no best period found for this object, skipping...

# %%
spdm = periodbase.stellingwerf_pdm(dates,fluxes,errs)
# Out:
# [I 200817 14:15:37 spdm:337] using autofreq with 1580 frequency points, start P = 0.100, end P = 31.690
# [I 200817 14:15:37 spdm:349] using 6 workers...

# %%
cp = checkplot.checkplot_png(spdm, dates, fluxes, errs)
# Out:
# [I 200817 14:15:40 nonphysical:216] spline fit done. nknots = 13,  chisq = 13483042.14862, reduced chisq = 9848.82553
# [I 200817 14:15:40 png:696] plotting phased LC with period 26.407967, epoch 1966.83444
# [I 200817 14:15:40 nonphysical:216] spline fit done. nknots = 13,  chisq = 13614096.75173, reduced chisq = 9944.55570
# [I 200817 14:15:41 png:696] plotting phased LC with period 13.203984, epoch 1966.77315
# [I 200817 14:15:41 nonphysical:216] spline fit done. nknots = 13,  chisq = 13406433.17117, reduced chisq = 9792.86572
# [I 200817 14:15:41 png:696] plotting phased LC with period 52.815935, epoch 1972.16715
# [I 200817 14:15:41 nonphysical:216] spline fit done. nknots = 13,  chisq = 13468220.67200, reduced chisq = 9837.99903
# [I 200817 14:15:41 png:696] plotting phased LC with period 22.635401, epoch 1942.37773
# [I 200817 14:15:41 nonphysical:216] spline fit done. nknots = 13,  chisq = 13443762.25461, reduced chisq = 9820.13313
# [I 200817 14:15:41 png:696] plotting phased LC with period 19.805976, epoch 1960.27585
# [I 200817 14:15:41 nonphysical:216] spline fit done. nknots = 13,  chisq = 13425464.30960, reduced chisq = 9806.76721
# [I 200817 14:15:41 png:696] plotting phased LC with period 31.689561, epoch 1972.14672
# [I 200817 14:15:41 nonphysical:216] spline fit done. nknots = 13,  chisq = 13510761.07781, reduced chisq = 9869.07310
# [I 200817 14:15:41 png:696] plotting phased LC with period 17.605312, epoch 1961.03182
# [I 200817 14:15:42 png:1233] checkplot done -> checkplot.png

# %%
Image('0000839-checkplot-spdm.png')

# %%
print('PDM algorithm:',(spdm['nbestperiods']),'(days)')
# Out:
# PDM algorithm: [26.407967483333245, 22.635400699999924, 19.805975612499935, 31.689560979999893, 17.605311655555496] (days)
