# %%
from astropy.table import Table
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
outpath='HAT-264-0000530.rlc.tfalc'
data=Table.read(outpath,format='ascii')
t=data['col2']
mag=data['col8']

# %%
plt.figure(figsize=(20,8))
plt.plot(t,mag,'yo',markersize=10,label='HAT-264-0000530')
plt.ylabel('Relative Magnitude')
plt.xlabel('time (BJD-2454833)')
# Out:
# Text(0.5, 0, 'time (BJD-2454833)')

# %%
import astrobase
from astrobase import periodbase, checkplot
periodbase.use_astropy_bls()
# Out:
# [I 200815 13:54:58 __init__:84] An Astropy implementation of BLS is available because Astropy >= 3.1.
# [I 200815 13:54:58 __init__:86] If you want to use it as the default periodbase BLS runner, call the periodbase.use_astropy_bls() function.

# %%
dates=data['col2']
fluxes=data['col8']
errs=fluxes*0.01

# %%
glsp = periodbase.pgen_lsp(dates,fluxes,errs)
# Out:
# [I 200815 13:55:03 zgls:597] using autofreq with 1580 frequency points, start P = 0.100, end P = 31.690
# [I 200815 13:55:03 zgls:607] using 6 workers...

# %%
cp = checkplot.checkplot_png(glsp, dates, fluxes, errs)
# Out:
# [I 200815 13:55:07 nonphysical:216] spline fit done. nknots = 13,  chisq = 13430353.71424, reduced chisq = 9911.70016
# [I 200815 13:55:07 png:696] plotting phased LC with period 0.397112, epoch 1940.47757
# [I 200815 13:55:07 nonphysical:216] spline fit done. nknots = 13,  chisq = 13542966.59721, reduced chisq = 9994.80930
# [I 200815 13:55:07 png:696] plotting phased LC with period 0.198556, epoch 1940.47757
# [I 200815 13:55:07 nonphysical:216] spline fit done. nknots = 13,  chisq = 13463277.19532, reduced chisq = 9935.99793
# [I 200815 13:55:07 png:696] plotting phased LC with period 0.794225, epoch 1940.47757
# [I 200815 13:55:07 nonphysical:216] spline fit done. nknots = 13,  chisq = 13485519.35564, reduced chisq = 9959.76319
# [I 200815 13:55:07 png:696] plotting phased LC with period 0.226354, epoch 1963.56534
# [I 200815 13:55:07 nonphysical:216] spline fit done. nknots = 13,  chisq = 13436931.39726, reduced chisq = 9916.55454
# [I 200815 13:55:07 png:696] plotting phased LC with period 0.282438, epoch 1957.98748
# [I 200815 13:55:07 nonphysical:216] spline fit done. nknots = 13,  chisq = 13474620.35950, reduced chisq = 9944.36927
# [I 200815 13:55:07 png:696] plotting phased LC with period 0.138141, epoch 1965.34290
# [I 200815 13:55:08 nonphysical:216] spline fit done. nknots = 13,  chisq = 13457674.63232, reduced chisq = 9939.19840
# [I 200815 13:55:08 png:696] plotting phased LC with period 0.176053, epoch 1940.47757
# [I 200815 13:55:09 png:1233] checkplot done -> checkplot.png

# %%
from IPython.display import Image
Image('0000530-checkplot-glsp.png')

# %%
glsp
# Out:
# {'bestperiod': 0.39711233295739395,
#  'bestlspval': 0.008335261607353046,
#  'nbestpeaks': 5,
#  'nbestlspvals': [0.008335261607353046,
#   0.007568394449386477,
#   0.00708410683015419,
#   0.006333916259487584,
#   0.00619105636790199],
#  'nbestperiods': [0.39711233295739395,
#   0.2263540297857146,
#   0.28243818333333365,
#   0.13814108182214488,
#   0.176053134277778],
#  'lspvals': array([0.00090295, 0.00110408, 0.00165993, ..., 0.00037757, 0.00095223,
#         0.00147404]),
#  'omegas': array([ 0.19827301,  0.23792761,  0.27758222, ..., 62.7335807 ,
#         62.7732353 , 62.8128899 ]),
#  'periods': array([31.68956417, 26.40797014, 22.63540298, ...,  0.10015665,
#          0.10009338,  0.10003019]),
#  'method': 'gls',
#  'kwargs': {'startp': None,
#   'endp': None,
#   'stepsize': 0.0001,
#   'autofreq': True,
#   'periodepsilon': 0.1,
#   'nbestpeaks': 5,
#   'sigclip': 10.0}}

# %%
print('LS algorithm:',(glsp['nbestperiods']),'(days)')
# Out:
# LS algorithm: [0.39711233295739395, 0.2263540297857146, 0.28243818333333365, 0.13814108182214488, 0.176053134277778] (days)

# %%
bls=periodbase.bls_parallel_pfind(dates,fluxes,errs)
# Out:
# [I 200815 13:55:41 abls:919] min P: 0.1, max P: 100.0, nfreq: 126632, minfreq: 0.01, maxfreq: 10.0
# [I 200815 13:55:41 abls:922] autofreq = True: using AUTOMATIC values for freq stepsize: 7.889032447996576e-05, ndurations: 100, min transit duration: 0.01, max transit duration: 0.4
# [W 200815 13:55:41 abls:964] the requested max P = 100.000 is larger than the time base of the observations = 31.690,  will make minfreq = 2 x 1/timebase
# [W 200815 13:55:41 abls:969] new minfreq: 0.06311225958397261, maxfreq: 10.0
# [I 200815 13:55:41 abls:980] using 6 workers...
# [I 200815 13:55:41 abls:1090] worker 1: minfreq = 0.063112, nfreqs = 21105
# [I 200815 13:55:41 abls:1090] worker 2: minfreq = 1.728093, nfreqs = 21105
# [I 200815 13:55:41 abls:1090] worker 3: minfreq = 3.393073, nfreqs = 21105
# [I 200815 13:55:41 abls:1090] worker 4: minfreq = 5.058053, nfreqs = 21105
# [I 200815 13:55:41 abls:1090] worker 5: minfreq = 6.723033, nfreqs = 21105
# [I 200815 13:55:41 abls:1090] worker 6: minfreq = 8.388014, nfreqs = 21107
# [I 200815 13:55:41 abls:1092] running...
# [E 200815 13:55:53 abls:1125] no finite periodogram values for this mag series, skipping...

# %%
cp = checkplot.checkplot_png(bls, dates, fluxes, errs)
# Out:
# [W 200815 13:55:55 png:1142] no best period found for this object, skipping...

# %%
spdm = periodbase.stellingwerf_pdm(dates,fluxes,errs)
# Out:
# [I 200815 13:55:59 spdm:337] using autofreq with 1580 frequency points, start P = 0.100, end P = 31.690
# [I 200815 13:55:59 spdm:349] using 6 workers...

# %%
cp = checkplot.checkplot_png(spdm, dates, fluxes, errs)
# Out:
# [I 200815 13:56:04 nonphysical:216] spline fit done. nknots = 13,  chisq = 13490934.00182, reduced chisq = 9956.40886
# [I 200815 13:56:04 png:696] plotting phased LC with period 19.805978, epoch 1960.15324
# [I 200815 13:56:04 nonphysical:216] spline fit done. nknots = 13,  chisq = 13562975.54355, reduced chisq = 10009.57605
# [I 200815 13:56:04 png:696] plotting phased LC with period 9.902989, epoch 1950.05999
# [I 200815 13:56:04 nonphysical:216] spline fit done. nknots = 13,  chisq = 13468163.74431, reduced chisq = 9939.60424
# [I 200815 13:56:04 png:696] plotting phased LC with period 39.611955, epoch 1972.16714
# [I 200815 13:56:04 nonphysical:216] spline fit done. nknots = 13,  chisq = 13548098.45495, reduced chisq = 9998.59665
# [I 200815 13:56:04 png:696] plotting phased LC with period 2.685556, epoch 1940.47757
# [I 200815 13:56:04 nonphysical:216] spline fit done. nknots = 13,  chisq = 13549952.64724, reduced chisq = 9999.96505
# [I 200815 13:56:04 png:696] plotting phased LC with period 11.317701, epoch 1963.09541
# [I 200815 13:56:04 nonphysical:216] spline fit done. nknots = 13,  chisq = 13518112.76445, reduced chisq = 9976.46698
# [I 200815 13:56:04 png:696] plotting phased LC with period 0.149338, epoch 1948.69108
# [I 200815 13:56:04 nonphysical:216] spline fit done. nknots = 13,  chisq = 13507406.93310, reduced chisq = 9968.56600
# [I 200815 13:56:04 png:696] plotting phased LC with period 13.203985, epoch 1953.79898
# [I 200815 13:56:05 png:1233] checkplot done -> checkplot.png

# %%
Image('0000530-checkplot-spdm.png')

# %%
print('PDM algorithm:',(spdm['nbestperiods']),'(days)')
# Out:
# PDM algorithm: [19.805977606250025, 2.685556285593224, 11.317701489285728, 0.1493381911875591, 13.20398507083335] (days)
